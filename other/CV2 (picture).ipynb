# %% [markdown]
# __[blog c](https://blog.gtwang.org/programming/opencv-basic-image-read-and-write-tutorial/)__

# %%
import numpy as np
import cv2

# %%
img = cv2.imread('Folder_test/img (1).png')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (500, 500, 3)

# %% [markdown]
# __[show rgb](https://www.pyimagesearch.com/2014/11/03/display-matplotlib-rgb-image/)__

# %%
#cv2 的 rgb 順序錯了
from matplotlib import pyplot as plt
plt.imshow(img, interpolation='nearest')
plt.show()

# %%
#改進
plt.axis("off")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(gray_image.shape)
plt.imshow(gray_image,cmap="gray")
# Out:
# (500, 500)

# %% [markdown]
# __[blog c](http://monkeycoding.com/?p=570)__

# %%
#模糊化
img1 = cv2.GaussianBlur(img,(5,5),0)
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
plt.show()

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img1 = cv2.GaussianBlur(gray_image,(5,5),0)
canny = cv2.Canny(img1, 10, 30)
plt.imshow(canny,cmap="gray")
