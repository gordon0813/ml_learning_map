# %%
def decode_to_dic(s):
    temp=s.split("\n")
    temp=[x.split(",") for x in temp]
    dic={}
    for i in temp:
        try:
            dic[i[0]]=float(i[1])
        except:
            print(i,"error")
        
    return dic
def decode_txt(a):
    alist=a.split("\n>->")
    re_=[]
    for i in range(len(alist)):
        temp_word=alist[i].split("(*)")
        if (len(temp_word)>2):
            re_.append(singleword(temp_word))       
    #alist=[x.split("(*)") for x in alist]    
    return re_
class singleword:
    def __init__(self,L):
        self.word=L[0]
        self.id=L[1]
        self.type=L[2]
        self.pword=L[5]
        self.linktype=L[3]
        self.tag=[]
    def show(self):
        print(self.word,self.type,self.index,"  ",self.pword,self.linktype,self.tag)
    def setindex(self,p):
        self.index=p
def change_to_word(wL):
    return [singleword(wL[x]) for x in range(1,len(wL)) ]
def decode_article(a):
    re_article=[]
    re=a.split("<=sep=>")
    re=[x.split("<=set=>") for x in re]
    for i in re:
        temp=[]
        for j in i:
            temp.append(decode_txt(j))
        re_article.append(temp)
    return re_article
def get_str(needlist,spot1):
    temp=spot1.wordtype==needlist[0]
    for j in range(1,len(needlist)):
        temp=temp+(spot1.wordtype==needlist[j])
    return " ".join(spot1.word[temp])
def get_str_tf(needlist,spot1):
    temp=spot1.wordtype==needlist[0]
    for j in range(1,len(needlist)):
        temp=temp+(spot1.wordtype==needlist[j])
    return temp
def filter_ratio(mat,from_a=0,to_b=0):
        if(from_a>=to_b):
            return None
        else:
            narray=np.array(mat)
            narrayindoc=np.sum(np.heaviside(narray, 0),0 )
            narrayratio=narrayindoc/narray.shape[0]
            ntfa=from_a<narrayratio
            ntfb=narrayratio<=to_b
            ntf1=ntfa*ntfb
            return ntf1

def give_rank(dic,word,c=0):
    re_mat=[]
    for i in word:
        try:
            re_mat.append(dic[i])
        except:
            re_mat.append(0)
    return re_mat
def create_dic(needword,word,mat):
    needword=list(needword)
    word=list(word)
    dic={}
    for i in needword:
        dic[i]=mat[word.index(i)]
    return dic   
def create_list(needword,word,mat):
    needword=list(needword)
    word=list(word)
    
    relist=[]
    for i in needword:
        relist.append([i,mat[word.index(i)]])    
    return relist 
import itertools
class spot_tfidf:
    def __init__(self,tf_mat,word,title):
        self.mat=self.avgm(tf_mat)
        self.word=word
        self.title=title
    def get_mat(self,title_):
        for i in range(len(self.title)):
            if(title_ == self.title[i]):
                temp=i
                break
        return self.mat[i]
    def spword_tf(self,needlist,batch=2):
        temp=[self.get_mat(x) for x in needlist]
        temp=list(itertools.combinations(temp,batch))
        temp=np.sum(np.array([np.multiply.reduce(np.array(x)) for x in temp]),0)
        return temp    
    def avgm(self,m):                 #對x向除以sum
        s=(np.sum(m,1))
        m1=m/(s.reshape(s.shape[0],1)+0.000000001)
        return m1  
    def most_similar(self,mat):
        temp=self.mat*mat
        return np.sum(temp,1)
    def filter_ratio(self,from_a=0,to_b=0):
        if(from_a>=to_b):
            return None
        else:
            narray=np.array(self.mat)
            narrayindoc=np.sum(np.heaviside(narray, 0),0 )
            narrayratio=narrayindoc/narray.shape[0]
            ntfa=from_a<narrayratio
            ntfb=narrayratio<=to_b
            ntf1=ntfa*ntfb
            return ntf1   
from sklearn import feature_extraction
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
class spot:
    def __init__(self,s):
        temp=decode_article(s)
        self.spot=[]
        for i in temp:
            if(len(i)>2):
                self.spot.append(i)
        self.wordtype=[]
        self.word=[]
        self.sentence=[]
        self.article=[]
        self.tags={}
        for art,arti in zip(self.spot,range(len(self.spot))):
            for sent,senti in zip(art,range(len(art))):
                for word in sent:
                    self.article.append(arti)
                    self.sentence.append(senti)
                    self.word.append(word.word)
                    self.wordtype.append(word.type)
        self.article=np.array(self.article)
        self.sentence=np.array(self.sentence)
        self.word=np.array(self.word)
        self.wordtype=np.array(self.wordtype)
    def show_all(self):
        for i in self.word:
            print(i,end="")
class look_into_article:
    def __init__(self,spot,article_=1):
        temp=spot.article==article_
        self.word=spot.word[temp]
        self.sentence=spot.sentence[temp]
    def show_article(self):
        print("".join(inspect_article.word))
    def set_article_rank(self,rank):
        if(len(rank)==len(self.word)):
            self.rank=np.array(rank)
        else:
            print("長度不合")

# %% [markdown]
# ## 載入需要資料

# %%
with open ('D:/data/final_project/食記dic.csv',"r",encoding="utf8") as file:
    sfood=file.read()
with open ('D:/data/final_project/交通dic.csv',"r",encoding="utf8") as file:
    stravel=file.read()
with open ('D:/data/final_project/住宿dic.csv',"r",encoding="utf8") as file:
    shotel=file.read()

# %%
three_dict=[]
three_dict.append(decode_to_dic(sfood))
three_dict.append(decode_to_dic(stravel))
three_dict.append(decode_to_dic(shotel))
# Out:
# [''] error
# [''] error
# [''] error

# %%
txtlist=[]
import os,sys
dirs = os.listdir( "D:/data/final_project/article" )
print(dirs)
# Out:
# ['AEON MALL OKINAWA RYCOM.txt', 'AEON北谷店 .txt', 'Ashibinaa Outlet .txt', 'BIC Camera難波店 .txt', 'BIOS之丘 .txt', 'Busena海中公園 .txt', 'Caretta汐留 .txt', 'DiverCity .txt', 'HEP FIVE摩天輪 .txt', 'JR TOWER T38展望室 .txt', 'Mild Seven之丘 .txt', 'ORION 啤酒名護工廠 .txt', 'OTS臨空豐崎營業所.txt', '一澤帆布 .txt', '三井Outlet Park大阪鶴見 .txt', '三井outlet 倉敷 .txt', '三十三間堂.txt', '三千院.txt', '三宮中心街 .txt', '三年坂.txt', '三角市場.txt', '三鷹之森吉卜力美術館 .txt', '上賀茂神社.txt', '上野 .txt', '上野動物園.txt', '上野恩賜公園.txt', '上野東照宮.txt', '上高地.txt', '下北澤 .txt', '下鴨神社.txt', '不忍池.txt', '世界大溫泉 .txt', '世豊商店.txt', '中之島 .txt', '中城公園.txt', '中島公園.txt', '中洲.txt', '中洲屋台.txt', '中禪寺湖 .txt', '主計町茶屋街.txt', '九州鐵道紀念館 .txt', '二年坂.txt', '二月堂.txt', '二木果子 .txt', '二条市場.txt', '二條城 .txt', '二荒山神社.txt', '五稜郭.txt', '井之頭恩賜公園.txt', '亞斗夢之丘 .txt', '交通.txt', '京都塔 .txt', '京都大學.txt', '京都御所.txt', '京都御苑.txt', '京都拉麵小路 .txt', '京都
.txt', '富士電視台 .txt', '富田農場 .txt', '富良野市集 .txt', '富良野芝士工房 .txt', '富良野葡萄酒工廠 .txt', '寧寧之道 .txt', '小丸子博物館.txt', '小倉城.txt', '小樽出拔小路.txt', '小樽浪漫館.txt', '小樽運河.txt', '小樽音樂盒堂 .txt', '小田急百貨店新宿店.txt', '小石川後樂園 .txt', '層雲峽 .txt', '岡山城.txt', '岡山後樂園 .txt', '岡本織物店.txt', '嵐山.txt', '嵐山竹林.txt', '嵯峨野觀光鐵道.txt', '川平灣.txt', '川越冰川神社 .txt', '巢鴨地藏通商店街 .txt', '帆船型觀光船聖瑪麗亞號.txt', '常寂光寺.txt', '平安神宮.txt', '平等院.txt', '平等院表參道.txt', '平野神社.txt', '座喜味城跡.txt', '廣島城 .txt', '廣島平和紀念公園 .txt', '建仁寺.txt', '弘前城.txt', '御堂筋.txt', '御殿場 Premium Outlet .txt', '心齋橋.txt', '心齋橋大丸百貨 .txt', '心齋橋筋商店街.txt', '忍野八海.txt', '忠犬八公 .txt', '思出橫丁 .txt', '戎橋.txt', '拼布之路 .txt', '摩周湖.txt', '摩耶山.txt', '支笏湖.txt', '新京極商店街.txt', '新宿御苑.txt', '新宿機器人餐廳 .txt', '新梅田食道街.txt', '新榮之丘 .txt', '日之出公園.txt', '日光東照宮.txt', '日本橋.txt', '早稻田大學 .txt', '旭山動物園.txt', '旭川拉麵村 .txt', '明治神宮.txt', '明治神宮外苑.txt', '明石海峽大橋.txt', '春日大社.txt', '昭和新山.txt', '時計台.txt', '晴明神社.txt', '晴空塔.txt', '會津若松城 .txt', '有樂町 .txt', '有馬溫泉 .txt', '朝日之丘公園 .txt', '本能寺.txt', '札幌啤酒園.txt', '札幌圓山公園 .txt', '札幌拉麵橫丁 .txt', '札幌電視塔 .txt', '東京大學.txt', '東京巨蛋 .txt', '東京彩虹橋 .txt', '東京站一番街 .txt', '東京迪士尼樂園 .txt', '東京迪士尼海洋 .txt', '東京都廳 .txt', '東京鐵塔 .txt', '東京鐵塔海賊王主題樂園 .txt', '東大寺.txt', '東寺.txt', '東本願寺.txt', '東福寺.txt', '東茶屋街 .txt', '松山城.txt', '松本城.txt', '栗林公園.txt', '根津神社.txt', '格子之家 .txt', '梅小路公園.txt', '梅田 .txt', '梅田空中庭園展望台.txt', '森林精靈陽台 .txt', '森美術館.txt', '榮町市場.txt', '橫濱LANDMARK TOWER .txt', '橫濱中華街.txt', '橫濱元町商店街.txt', '橫濱泡麵博物館 .txt ...

# %% [markdown]
# ## 載入資料

# %%
spotlist=[]
dirs=dirs[0:100]
dirs=["黑門市場.txt","三年坂.txt","淺草.txt"]
for i in dirs:
    with open("D:/data/final_project/article/"+i,"r",encoding="utf8") as file:
        spotlist.append(spot(file.read()))

# %%
three_dict[0]["飯店"]
# Out:
# 0.022865497979547494

# %% [markdown]
# # 過濾文章

# %%
inspect_article=look_into_article(spotlist[0],5)
article_rank=give_rank(three_dict[0],inspect_article.word)
article_rank_t=give_rank(three_dict[1],inspect_article.word)
層可以現烤現吃最上層最便宜的應該1600<U+5186>左右(100g)...（阿姨：叫我煎肉工資可是很高的！）選完最上排之後就排隊等阿姨煎好給你們現吃囉！（真的超級香差一點就下手了但一想到我的心齋橋血拼行程就還是收手了哈哈）6.三都屋三都屋地址：大阪市中央區日本橋1-22-21TEL：06-6641-0454FAX：06-6641-4779營業時間、：8:30～19:00(平日)、、、、9:30～18:00（星期日·國定假日）休假日：第2星期日,8/15盂蘭盆節官方網站：請按此因為看了雙星陰陽師的關係我跟阿邦師這趟來日本超想吃日本傳統點心的啦！！（尤其是萩餅）萩餅就是這種外面包紅豆裡面包甜甜糯米的點心這間的萩餅普普通通（我印象中的非常好吃）但是這家的<U+304D><U+306A><U+3053>(KI-NA-KO)餅（也就是黃豆粉餅台灣好像叫蕨餅）非常的好吃>w<淋上黑糖甜而不膩又爽口還入口及化又有黃豆粉的香味<U+2665>大推大推～推薦度：、★、★、★、★、★、（滿分五星）7.神戶屋肉店神戶屋肉店地址：大阪市中央區日本橋2-2-16TEL：06-6641-0029、(烤肉店、06-6641-0053)FAX：06-6641-5929營業時間、：上等肉店→、8:00～18:00；烤肉店→、平日、16:00～24:00；六日及國定假日、12:00～24:00休假日：全年不休息官方網站：請按此這間一樣預算不夠沒吃ＱＱ另外以下是一些在街邊看到的小吃：牛肉豆腐甜甜香香的還滿好吃應該算是很當地的一道美食沒有驚人的美味但是在冬天來一份熱呼呼的牛肉豆腐煮就是會覺得很舒服<U+2665>一份500<U+5186>路邊炸雞忘記多少錢印象中非常便宜但可怕的味道至今難忘閃光跟我老爸皺著眉頭吃我則是吃一口馬上反胃非常不新鮮....炸得在香酥都沒用大家在外地買食物真的要小心啊如果買到地雷或不新鮮也千萬不要硬吃在國外生病很麻煩的＠＠培根包飯糰看起來很好吃可是無法每一樣都吃到啊><跟牛肉豆腐同一家大阪香腸也是看起來很好吃>///<草莓大福冬季期間限定商品可惜這時候剛吐完炸雞沒食慾...一份300<U+5186>串燒丸子跟看起來很好吃的日本餅串燒丸子在711跟超市就有賣跟這種路邊貪吃起來都差不多好吃但711比較便宜ＸＤ長相很奇特的辣椒狀蘿蔔吃起來普普通通襪子專賣店想著要去心齋橋買就沒在這裡下手了結果沒時間回來逛QQ看起來超厲害的現烤鰻魚&牛肉串＆鰻魚蛋捲可惜走到這裡已經 ...

# %%
import matplotlib.pyplot as plt
plt.plot(list(range(len(article_rank))),article_rank)
plt.show()

# %%
rank_f=[0]
rank_t=[0]
rank_h=[0]


for i in range(1,inspect_article.sentence[-1]):
    #print(" ".join(inspect_article.word[inspect_article.sentence==i]))
    temp=np.array(article_rank)[inspect_article.sentence==i]
    rank_f.append(np.sum(temp)/(len(temp)+1))
    temp=np.array(article_rank_h)[inspect_article.sentence==i]
    rank_h.append(np.sum(temp)/(len(temp)+1))
    temp=np.array(article_rank_t)[inspect_article.sentence==i]
    rank_t.append(np.sum(temp)/(len(temp)+1))
    #print(rank[i])
print(sum(rank_f)/len(rank_f))
print(sum(rank_t)/len(rank_t))
print(sum(rank_h)/len(rank_h))
def get_blurry(mat):
    remat=mat
    for i in range(1,9):
        remat=remat+(np.roll(mat,i)+np.roll(mat,-i))*0.8**i
    return remat
def compare_two(m1,m2):
    temp=(m1-m2)
    return temp
    
rank_sp = get_blurry(compare_two(np.array(rank_f),0.5*(np.array(rank_t)+np.array(rank_h))))
avg_sp=sum(rank_f)/len(rank_f)*3-0.5*sum(rank_t)/len(rank_t)-0.5*sum(rank_h)/len(rank_h)

len_use=0
left=[]
for i in range(1,inspect_article.sentence[-1]):
    
    if(rank_sp[i]>avg_sp):
        print(" ".join(inspect_article.word[inspect_article.sentence==i]))
        
        len_use+=1
    else:
        left.append(" ".join(inspect_article.word[inspect_article.sentence==i]))
        print("=============",end="^")
# Out:
# 0.006602616095362159
# 0.004867289064104528
# 0.0046672809629444145
# =============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^地址 ： 大阪市中央 <U + 533A > 日本橋 1 - 17 - 7
# TEL ： 06 ( 6641 ) 1595
# FAX ： 06 ( 6631 ) 8867
# 營業 時間 、 ： 6:00 ～ 17:00
# 休假日 ： 星期日
# 國定 假日
# 官方 網站 ：
# 這次 來 黑 門
# 吃到 這個 油花 滿滿 鮪魚腹
# 真的 是 被 我 一 講 再 講 ＸＤ
# 魚丸 位在 從 日本橋 站 10 號 出口 走 出來
# 第一個 進 黑門市場 的 門口 左手 邊 的 店家
# 我們 平日 早上 來
# 生意 就 已經 很 好 了
# 雖然 沒有 到 大排長龍 的 程度
# 但 還是 很多 人 在 排隊
# 挑選
# 鮪魚 跟 鮭魚 都 有 賣 （ 但 好像 主打 鮪魚 ）
# 店家 門口 還有 一個 標明 鮪魚 部位 的 告示牌
# 最 吸引 我 下手 的 是 下面 這 三 樣 ：
# http://imgur . com/MUfNhdm
# 片數 很多
# 看起來 很 新鮮 的 鮪魚 肉片
# 800 元 ！
# http://imgur . com/WEa9KSx
# 這個 就是 傳說 中 ５ 片 880 <U + 5186 > 的 鮪魚腹 ！！ （ 我 只 看 的 懂 、、 鮪中 < U + 3068 > < U + 308D > ＝ 鮪魚 中段 腹 、 、 XDDD ）
# http://imgur . com/ZQ7bbk9
# < U + 30AB><U+30DE><U+30C8 > < U + 30ED> ( kamatoro ) 據說 是 鮪魚 鰓 以下 最好 吃 的 部位
# 也 是 全身 最 昂貴 的
# ５ 片 要 1300 元
# 不過 我 購買 當時 只 看 它 均勻 分布 的 油花
# 就 決定 他 一定 是 最 好吃 的 了 ＸＤ
# 後來 閃光 提醒 我 各 買 一盒
# 才 能 比較 看看 口味
# 首先 先吃 、 鮪中 < U + 3068 > < U + 308D > ＝ 鮪魚 中段 腹 、
# 第一 口 下去 就是 、 新鮮 、 好吃 、 ！ 味道 也 還 算 滿 濃郁 的 <U + 2665 >
# 可是 下 一口 吃 了 這個 < U + 30AB><U+30DE><U+30C8 > < U + 30ED> ( kamatoro ) 之後 ...
# OMG ！ 根本就是 天殺 的 好吃 ！！
# 人生 第二 口吃 這 種 鮪魚腹 （ 第一 次 大概 要 回溯到 2008年 ... 這個 故事 有空 再 講 XD ）
# 真的 可以 說 是 入口 即化
# 而且 滿嘴 的 香味 鮮味
# 只有 感動 兩 個 字 可以 形容 ！！
# 雖然 只有 五 片
# 還是 強烈 推薦 一定 要 來 體會 看看 這個 永生 難忘 的 滋味 啊 ！
# 推薦 度 ： 、 ★ 、 ★ 、 ★ 、 ★ 、 ★ 、 （ 滿分 五星 ）
# =============^=============^=============^=============^=============^=============^營業 時間 、 ： 8:00 ～ 16:00
# =============^=============^=============^=============^前面 忘記 說
# 黑門 這邊 有 很多 店家 都 有 中文 說明
# 超級 多 可以 現烤 的 海鮮
# 每 一樣 都 好 想 點 >///<
# 尤其 海膽 最 誘人 了 ！！
# 但 最後 因為 口袋 不夠 深
# 選擇 了 兩 支 串燒 鰻魚
# 只顧 著 吃 就 忘記 拍照 了 ...
# 這家 的 串燒 鰻魚 還 算 不錯
# 燒烤 醬汁 很香
# 油脂 香軟 豐富
# 推薦 度 ： 、 ★ 、 ★ 、 ★ 、 ★ 、 ☆ 、 （ 滿分 五星 ）
# 3.<U+306A> < U + 3079 > < U + 3058 > ( Nabeji ) 蔬果
# < U + 306A> < U + 3079 > < U + 3058 > ( Nabeji ) 蔬果
# 地址 ： 大阪市 中央區 日本橋 1 - 21 - 34
# TEL ： 06 - 6633-2228
# FAX ： 06 - 6633-2238
# 營業 時間 、 ： 7:00 ～ 19:00
# =============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^看起來 很 誘人
# 但是 太貴 了 買 不下 手ＸＤＤ
# 剛好 靠近 情人 節前 一週
# 還有 推出 情人節 限定 白巧克力 草莓 <U + 2665 >
# 推薦 度 ： 、 ★ 、 ★ 、 ★ 、 ★ 、 ☆ 、 （ 滿分 五星 ）
# 4.黑門 三平
# 黑門三平
# 地址 ： 大阪市 中央區 日本橋 1-22 - 25
# TEL ： 06 - 6634-2611 ； 0120-39-6358
# FAX ： 06 - 6634-2665
# 營業 時間 、 ： 9:00 ～ 18:30
# 休假日 ： 全年 不 休息
# =============^=============^好像 永遠 都 有 這麼 多 人 XD
# 入口 左邊 是 牛排 區
# 每 一塊 的 油花 都 好 漂亮 >///<
# 但是 一樣 預算 不夠
# 只好 先 聞香 別人 的 牛排 QQ （ 真的 超級 香 ！！ ）
# =============^=============^好 大好 大 的 蟹腳 啊 ！！！ （ 價格 也好 巨 啊 ＱＱ ）
# 握 壽司 的 油花 看起來 超級 誘人 <U + 2665 > <U + 2665 > <U + 2665 >
# 點 餐台 也 有 超 多 海鮮
# 都 是 比較 平價 的 海鮮
# 最後 我們 選 了 3支 780 <U + 5186 > 的 大 蝦子
# 很大 隻 肉 很多 很爽
# 但 吃 不 出來 新 不 新鮮 ＠ ＠
# 而且 買 了 才 知道 這個 是 不能 加熱 的
# 這種 天氣 ( 0 度 左右 ) 還是 要 吃 熱 的 好吃 >< ' '
# 還 買 了 這個 干貝
# 好吃 是 好吃
# 非常 Ｑ彈 多汁
# 但 非 ～～～常 非常 鹹＠ ＠
# 建議 很多 人 合 吃 一盤 嚐嚐 味道 就 好
# 推薦 度 ： 、 ★ 、 ★ 、 ★ 、 ★ 、 ☆ 、 （ 滿分 五星 ）
# 5.萬野<U + 7 DCF>本 店
# 萬野<U + 7 DCF>本 店
# 地址 ： 大阪市 中央區 日本橋 1-22 - 20
# TEL ： 06 - 6648-1129
# FAX ： 06 - 6648-1129
# 營業 時間 、 ： 8:00 ～ 19:00
# 休假日 ： 全年 不 休息
# =============^=============^種類 有 非常 多
# 很多 價格 看起來 也 很 親民
# =============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^我 跟 阿邦師 這 趟 來 日本
# 超想 吃 日本 傳統 點心 的 啦 ！ ！ （ 尤其 是 萩餅 ）
# 萩餅 就是 這種 外面 包 紅豆
# 裡面 包 甜甜 糯米 的 點心
# 這 間 的 萩餅 普普通通 （ 我 印象 中的 非常 好吃 ）
# 但是 這家 的 < U + 304 D > < U + 306A> < U + 3053 > ( KI - NA - KO ) 餅
# （ 也就是 黃豆 粉餅
# 台灣 好像 叫 蕨餅 ）
# 非常 的 好吃 >w <
# 淋 上 黑糖 甜而不 膩 又 爽口
# 還 入口 及 化
# 又 有 黃豆粉 的 香味 <U + 2665 >大 推大 推
# ～
# 推薦 度 ： 、 ★ 、 ★ 、 ★ 、 ★ 、 ★ 、 （ 滿分 五星 ）
# 7.神戶屋肉店
# 神戶屋肉店
# 地址 ： 大阪市 中央區 日本橋 2 - 2 - 16
# TEL ： 06 - 6641-0029 、 ( 烤肉店 、 06-6641-0053 )
# FAX ： 06 - 6641-5929
# 營業 時間 、 ：
# 上等 肉店 → 、 8:00 ～ 18:00 ；
# 烤肉店 → 、 平日 、 16:00 ～ 24:00 ； 六日 及 國定 假日 、 12:00 ～ 24:00
# 休假日 ： 全年 不 休息
# 官方 網站 ： 請 按 此
# 這 間 一樣 預算 不夠 沒 吃 ＱＱ
# 另外 以下 是 一些 在 街邊 看到 的 小吃 ：
# 牛肉 豆腐
# 甜甜 香香的 還 滿 好吃
# 應該 算是 很 當地 的 一道 美食
# 沒有 驚人 的 美味
# 但是 在 冬天 來 一 份 熱呼呼 的 牛肉 豆腐 煮 就是 會 覺得 很 舒服 <U + 2665 >
# 一份 500 <U + 5186 >
# 路邊 炸雞
# 忘記 多少 錢
# 印象 中 非常 便宜
# 但 可怕 的 味道 至今 難忘
# 閃光 跟 我 老爸 皺 著 眉頭 吃
# 我 則 是 吃 一口 馬上 反胃
# 非常 不 新鮮 ....炸得 在 香酥 都 沒用
# 大家 在 外地 買 食物 真的 要 小心 啊
# 如果 買 到 地雷 或 不 新鮮 也 千萬 不要 硬 吃
# 在 國外 生病 很
# 麻煩 的 ＠ ＠
# 培根 包飯 糰
# 看起來 很 好吃
# 可是 無法 每 一樣 都 吃到 啊 >< 跟 牛肉 豆腐 同一 家
# 大阪 香腸
# 也 是 看起來 很 好吃 >///<
# 草莓 大福
# 冬季 期間 限定 商品
# 可惜 這 時候 剛 吐完 炸雞 沒 食慾 ... 一份 300 <U + 5186 >
# 串燒 丸子 跟 看起來 很 好吃 的 日本 餅
# 串燒 丸子 在 711 跟 超市 就 有 賣
# 跟 這 種 路邊 貪吃 起來 都 差不多 好吃
# 但 711 比較 便宜 ＸＤ
# 長相 很 奇特 的 辣椒 狀 蘿蔔
# 吃 起來 普普通通
# 襪子 專賣店
# 想 著 要 去心齋橋 買 就 沒 在 這裡 下手 了
# 結果 沒 時間 回來 逛 QQ
# 看起來 超 厲害 的 現 烤 鰻魚 & 牛肉串 ＆ 鰻魚 蛋捲
# 可惜 走到 這裡 已經 差不多 飽 了
# 我們 在 京都 有 吃到 類似 的 牛肉串
# 雷 到 爆
# 不 知道 黑 門 的 好不好 吃XDD
# =============^=============^=============^忘記 一盒 多少 錢 了
# 印象 中 不 便宜
# 可是 看起來 就 覺得 超 甜 ！！
# 零食 店
# 還 好 沒 在 這邊 買
# 大部分 零食 都 是 心齋橋 比較 便宜
# 河豚 專賣店
# 還 可以 現場 自己 加 調味料
# 感覺 很 特別
# 但 我們 還是 不太 敢 吃
# 牛肉 御飯 糰
# 現場 聞 覺得 滿 香 的
# 咖哩 飯
# 網路 上 有的 網友 滿 推薦 的
# 油花 滿滿 的 牛肉串
# >///<
# 可惜 口袋 不夠 深不然 好 想 吃吃 看 ＱＱ
# 烤 地瓜 超香 的 <U + 2665 >
# 可以 生食 的 生蠔
# 看起來 好 鮮 美好 想 吃 啊 >///<
# =============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^營業 時間 、 ： 9:00 ～ 19:30
# =============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^營業 時間 、 ： 9：00 - 19：00
# =============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^但 公婆 都 覺得 吃完 精神 很 不錯
# =============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^=============^

# %%
print("過濾")
print("\n",len_use/len(rank_sp)*100,"%")
plt.plot(list(range(len(rank_sp))),rank_sp)
plt.plot(list(range(len(rank_sp))),avg_sp*np.ones(len(rank_sp)))
plt.plot()
plt.show()
for i in left:
    print(i)
# Out:
#  35.940409683426445 %
# 、 大阪 黑門市場 逛街 美食 藥妝懶人 包 總 整理 時間 Tue 、 May、、 2 、 15:51:21 、 2017
# 今年 員工 旅遊 去 了 大阪 玩 六 天 五夜
# 順手 整理 一下 懶人 包
# 非常 不 專業 的 小小 懶人 包 請 見諒 ><
# 有 任何 錯誤 歡迎 指正 或 鞭 小力 > < ' '
# 無 音樂 好 讀 圖文 網誌 板 :
# http://muah.blog/2017-04 - 26 - 167 /
# 日本 去 了 六 次
# 去 大阪 就 已經 佔 了 兩 次
# 還是 覺得 不管 再 去 幾 次
# 都 得 去逛 黑門市場 啊 ！
# 除了 因為 黑門市場 是 號稱 的 大阪 人 的 廚房
# 最 重要 的 是
# 愛吃 海鮮 和 牛 的
# 絕對 不能 錯過
# 因為 這邊 的 海鮮 海產 、 黑毛 和 牛 、 還有 各式各樣 的 新鮮 水果 等等
# CP 值 都 超高 的 啊 ！！
# 愛 逛 藥妝店 的 朋友
# 更 不能 放過 黑門市場
# 這裡 的 藥妝店 有時候 還 會 有 驚人 的 大 特價 ！
# --------------------------
# 黑門市場 簡介
#
# 店鋪 營業 時間 ： 約莫 都 從 、 早上 7:30 - 9: 00
# 開到 下午 15:30 - 19 : 00 左右
# 主打 特色 ： 平價 新鮮 生魚片 、 海鮮 海產 、 現 煎 和 牛 、 便宜 藥妝
# http://imgur . com/mP1dC 6 Z
# --------------------------
# 黑門市場 交通
# 最近 的 車站 ： 地鐵 日本橋 站
# 地鐵 御堂筋線 、 梅田站 ： 步行 8 分鐘
# 地鐵 御堂筋線 、 難波站 ： 步行 1 分鐘
# 地鐵千 日 前線 、 難波站 ： 步行 5 分鐘
# 地鐵千 日 前線 、 日本橋 站 ： 步行 1 分鐘
# 　(以上 資料 取自 百度 百科 ）
# http://imgur . com/68kFfYd
# 我們 是 從 動物園 前站 → 搭乘 <U + 583A >筋 線 → 到達 日本橋 站
# 10 號 出口 走 出來 之後
# 大約 １ 分鐘 就 會 到 黑門市場 囉 ！
# http://imgur . com/LpgK7z4
# --------------------------
# 黑門 市場 美食 地圖
# 這 是 這次 我 去 大阪 京都 自己 的 google 地圖
# 裡面 有 一個 黑門市場 的 圖 層
# 歡迎 大家 盡情 參考 囉 ！
# 艾咪 的 2017大阪 京都 旅遊 地圖
# 　https://goo.gl/bHJiiJ
# ---------------------------
# 黑門 市場 美食
# 1.魚丸 商店
# http://imgur . com/vCeHGFK
# 　　魚丸 商店 （ 頂級 鮪魚 腹肉 5 片 1380 <U + 5186 > ）
# 2.<U+30D5>< U + 30B8><U+30CE > ( Fujino ) 鮮魚 、 ( 藤野 鮮魚 )
# http://imgur . com/bV 98NFe
# 　　　<U+30D5>< U + 30B8><U+30CE > ( Fujino ) 鮮魚 、 ( 藤野 鮮魚 )
# 地址 ： 大阪市中央 <U + 533A > 日本橋 1 - 21 - 34
# TEL ： 06 - 6647 - 2950
# FAX ： 06 - 6647 - 2950
# 官方 網站 ：
# 這 間 <U+30D5>< U + 30B8><U+30CE > ( Fujino ) 鮮魚 、 ( 藤野 鮮魚 )
# 就 在 魚丸 的 對面
# 大部分 的 海鮮 都 可以 現 烤 來 吃
# 休假日 ： 8 / 15 盂蘭盆節 , 大年初一 ( 1/1 )
# 官方 網站 ：
# 有 來 黑門市場 的話
# 建議 一定 要 來 這 間 < U + 306A> < U + 3079 > < U + 3058 > ( Nabeji ) 蔬果 、 買 點 新鮮 的 當季 水果 來 吃 ！
# 2月份 的 當季 水果 是 草莓 ( 300 ) 跟 哈密瓜 ( 500 )
# 我們 各 買了 一份 來 吃
# 哈密瓜 很甜 又 多汁
# 草莓 普普通通
# 不酸 但 也 沒有 太 甜
# 但 汁 滿 多 又 大顆
# 還是 滿 爽 的 ！
# 還有 這 種 白色 草莓
# 官方 網站 ：
# 黑門 三平 也 是 以 現 燒烤 海鮮 肉類 為主
#
# 還有 應該 是 店 內 振店 之 寶
# 官方 網站 ： 請 按 此
# 這 間 也是 很 紅 但 預算 不夠 所以 沒有 吃到 ＱＱＱ
# 但是 不要 高興 得 太早
# 因為 ...
# 沒錯 ！！ 只有 最 上層 可以 現烤 現 吃
# 最 上層 最 便宜 的 應該 1600 <U + 5186 > 左右 ( 100 g ) ...
# （ 阿姨 ： 叫 我 煎肉 工資 可是 很高 的 ！ ）
# 選 完 最上 排 之後
# 就 排隊 等 阿姨 煎好 給 你們 現 吃 囉 ！
# （ 真的 超級 香
# 差一點 就 下手 了
# 但 一 想到 我 的 心齋橋 血拼 行程 就 還是 收手 了 哈哈 ）
# 6.三 都 屋
# 三都屋
# 地址 ： 大阪市 中央區 日本橋 1-22 - 21
# TEL ： 06 - 6641-0454
# FAX ： 06 - 6641-4779
# 營業 時間 、 ： 8:30 ～ 19:00 ( 平日 ) 、、、、 9:30 ～ 18:00 （ 星期日 · 國定 假日 ）
# 休假日 ： 第2 星期日 , 8 / 15 盂 蘭 盆 節
# 官方 網站 ： 請 按 此
# 因為 看 了 雙星 陰陽 師 的 關係
# 好像 可以 現烤 的 帝王 蟹腳 & 大 蝦子
# 某 間 海產店 外面 賣 的
# 白草莓
# 也 有 現 烤 生蠔
# 看起來 好 鮮 美好 想 吃 啊 >///<
# 不 知道 現烤 還 生 吃 的 鮭魚 串
# 色澤 很 美
# 感覺 很 新鮮
# 薯條 三兄弟
# 好像 比 機場 便宜 一點
# 北海道 限定 哈密瓜 Pocky
# 怎麼 會 跑到 大阪呢....
# 以上 給 大家 參考 囉 ！
# --------------------------------
# 黑門市場 藥妝店
# 1.<U + 30AF>< U + 30 B 9 > < U + 30EA >< U + 30AA> < U + 30FC>< U + 30A8>< U + 30B9><U+30C9 >< U + 30E9><U+30C4>< U + 30 B 0 > 、 ( KuSuRi < U + 014D>-ESuDoRaTsuGu )
# < U + 30AF>< U + 30 B 9 > < U + 30EA >< U + 30AA> < U + 30FC>< U + 30A8>< U + 30B9><U+30C9 >< U + 30E9><U+30C4>< U + 30 B 0 > 、 ( 黑 門店 )
# 地址 ： 大阪市中央 <U + 533A > 日本橋 1 - 21 - 3
# TEL ： 06 - 4396 - 3311
# FAX ： 06 - 4396 - 3311
# 休假日 ： 全年 不 休息
# 官方 網站 ： 請 按 此
# 這 間 有 很多 很 便宜 的 藥妝
# 可惜 沒有 時間 回來 買 ＱＱＱ
# 把 這次 來 拍到 的 價格 分享 給 大家 參考 ：
# 日本 UTENA 、 魚子醬 面膜
# 之前 非常 火紅
# 這裡 賣 一盒 425 <U + 5186 > ( 未 稅 ) （ 但 我 覺得 沒有 很好 用
# 之後 寫 開箱 文XDD ）
# Queen's 、 Premium 、 Mask 鑽石 女王 面膜
# 這個 就 真的 很 好 用
# 這裡 賣 一盒 670 <U + 5186 > ( 未 稅 )
# MINON 、 - 、 Amino 、 Moist 面膜
# 這個 聽說 很好 用
# 這裡 賣 一盒 1080 <U + 5186 > ( 未 稅 )
# 這次 比價 半天
# 一直 以為 自己 有 買了
# 結果 回到 台灣 才 發現 自己 根本 沒 買 嗚 嗚嗚 嗚嗚
# .....
# MINON 、 - 、 Amino 、 Moist 卸妝 ＆ 洗面乳
# 一樣 同 系列 通通 忘 了 買
# 一條 都 是 1280 <U + 5186 > ( 未 稅 )
# MINON 、 - 、 Amino 、 Moist 、 洗顏 粉& 保濕 化妝水
# 洗顏粉 一條 1280 <U + 5186 > ( 未 稅 ) ； 保濕 化妝水 一條 1630 <U + 5186 > ( 未 稅 )
# MINON 、 - 、 Amino 、 Moist 、 保濕 乳液 & 保濕 霜
# 保濕 乳液 一條 1780 <U + 5186 > ( 未 稅 ) ； 保濕 霜 一條 1980 <U + 5186 > ( 未 稅 )
# MINON 、 - 、 Amino 、 Moist 、 沐浴乳
# 有分 一般 包裝 跟 環保 補充 包
# 一般 包裝 一罐 840 <U + 5186 > ( 未 稅 )
# Curel 、 珂潤 保濕 化妝水 & 乳液
# 敏感肌 都 很 愛 用 XD
# 一罐 都 是 1124 <U + 5186 > ( 未 稅 )
# Curel 、 珂潤 保濕 洗面乳
# 洗面乳 沒用 過
# 但 他 的 卸妝 真的 卸 的 很 乾淨
# 也 不會 太 黏稠 讓 皮
# 膚 不 舒適
# 台灣 賣 很 貴
# 所以 來 日本 可以 放心 囤貨
# 可惜 這裡 賣光
# 洗面乳 一罐 848 <U + 5186 > ( 未 稅 )
# SANTENEO 參天 、 Beauteye 玫瑰 眼藥水
# 這個 也是 以為 自己 買了 回 台灣 才 發現 根本 沒 買 ...
# 然後 也 沒 拍到 價錢 ... 只能 告訴 你們 這裡 有 賣 QQ
# PAIR 、 ACNES 、 痘痘 藥
# 一樣 回 台灣 才 發現 根本 沒 買 = 、 = （ 玩太 開心 真的 會 忘記 自己 在 幹 嘛
# ... ）
# 這裡 賣 一條 743 <U + 5186 > ( 未 稅 )
# 脂流 茶
# 看起來 很 厲害
# 但 最後 也 忘記 買了
# 想 減肥 的 可以 試試看
# 這裡 賣 一盒 498 < U + 5186 > ( 未
# 稅 )
# 協和藥品 的 液体 絆創膏 EX
# 回 台灣 才 發現 根本 沒 買 = 、 =
# 下次 去 一定 要 買 啊 可惡 啊 啊啊
# 這裡 賣 一條 379 <U + 5186 > ( 未 稅 )
# 曼秀雷敦 的 液體 OK 蹦
# 這裡 賣 一條 552 <U + 5186 > ( 未 稅 )
# 小林 製藥 的 液體 OK 蹦
# 這裡 賣 一條 548 <U + 5186 > ( 未 稅 )
# < U + 30E1 > < U + 30E9><U+30CE > CC 美白
# 之前 有 介紹 過 這 牌子 的 化妝水
# 他 的 精華 液 一樣 好用 又 便宜
# 這裡 賣 一條 933 <U + 5186 > ( 未 稅 )
# KOSE 、 光映 透 、 極 上 保濕 凝凍 面膜 、
# 也是 聽說 很好 用 結果 忘記 買 的 面膜 嗚嗚 （ 只好 再 去 一
# 次 日本 啦 ！ ( 大誤 ) ）
# 這裡 賣 一盒 475 <U + 5186 > ( 未 稅 )
# 伊勢半kissme 護手霜 、
# 這 條 回購 好 多次 了
# 台灣 也 有 賣
# 滋潤 度 不錯
# 而且 小條 放小 包
# 很 方便 <U + 2665 >
# 這裡 賣 一條 171 <U + 5186 > ( 未 稅 )
# 日本 樹惠 本舖 天然 樹 液 足底 舒適 貼片 、
# 總之 是 抱著 有趣 的 心情 買 來 試試看 的
# 但 看 網友 說 其實 根本就是 吸汗 變 黑
# 不確定 到底 有 沒有 實際 功效 ＠ ＠ 這 有 興趣 的 朋友 自己 買來 玩玩 看 啦 ！ 這裡 賣 一盒 1245 <U + 5186 > (
# 未 稅 )
# 2.<U + 30 B 3 > < U + 30AF><U+30DF>< U + 30 F3 > < U + 30C9 >< U + 30E9><U+30C3 >< U + 30 B 0 > 、 ( KoKuMin ) 國民 藥妝 、 ( 黑 門店 )
# < U + 30 B 3 > < U + 30AF><U+30DF>< U + 30 F3 > < U + 30C9 >< U + 30E9><U+30C3 >< U + 30 B 0 > 、 ( KoKuMin ) 國民 藥妝 、、 ( 黑 門店 )
# 地址 ： 大阪府大阪市中央 <U + 533A > 日本 橋二丁目 2 - 17
# TEL ： 06 - 6630-7055
# 官方 網站 ：
# 這 間 國民 藥妝 比起 上 一 間
# 有 更 多 的 彩妝
# 種類 也 更 齊全
# 但 有的 商品 價格 就 稍微 偏貴
# 給 大家 參考 囉 ！
# Curel 、 珂潤 保濕 洗面 乳＆ 卸妝 凝 露
# 這 間 比 上 一間 便宜 ！
# 洗面乳 沒用 過
# 但 他 的 卸妝 真的 卸 的 很 乾淨
# 也 不會 太 黏稠 讓 皮膚 不 舒適
# 台灣 賣 很 貴
# 所以 來 日本 可以 放心 囤貨
# 洗面乳 一罐 732 < U + 5186 > ( 未 稅 )
# 卸妝 凝 露 一罐 630 <U + 5186 > (
# 未 稅 )
# 肌美 精高 保濕 面膜 、
# 一樣 是 殘念 忘記 買 的
# 網友 都 很大 推 的 說 ...
# 這裡 賣 一盒 760 <U + 5186 > ( 未 稅 )
# Saborino 早安 面膜 、
# 一樣 是 殘念 忘記 買 （ 根本 把 腦待 留在 台灣 沒 帶 ）
# 這裡 賣 一包 1300 <U + 5186 > ( 未 稅 )
# 石澤研究所 - 透 明白 肌 面膜 、
# 這 款 是 當下 看 很 燒
# 但 來不及 回來 買
# 後來 看 網路 上 沒有 太多 評價
# 有人 用 過 可以 分享 嗎
# ～ （ 呼喊 ）
# 這裡 賣 一包 10 入 600 <U + 5186 > ( 未 稅 )
# KOSE 、 光映 透 、 極 上 保濕 凝凍 面膜 、
# 也是 聽說 很好 用 結果 忘記 買 的 面膜 嗚嗚 （ 只好 再 去 一
# 次 日本 啦 ！ ( 大誤 ) ）
# 這裡 賣 一盒 647 <U + 5186 > ( 未 稅 ) 。 （ 比 第一家貴 ）
# Queen's 、 Premium 、 Mask 鑽石 女王 面膜
# 這個 很好 用 很 保濕
# 這裡 賣 一盒 725 <U + 5186 > ( 未 稅 ) 。 （
# 比 第一家貴 ）
# 北海道 的 馬油 、
# 一直 有 聽到 很多 人 在 推薦 馬油 很 好 用
# 但 這次 摳摳 不夠 所以 沒有 買
# 這裡 三 個 不同 廠牌 各 賣 一盒 2500
# 2000
# 1980 <U + 5186 > ( 未 稅 )
# 資生堂 131 粉 底 刷 、
# 這裡 賣 一支 1440 <U + 5186 > ( 未 稅 ) 。 看到 網路 上 推薦 到 翻 了 但 買 回來 覺得 超 難
# 用
# 然後 某天 爬文 才 發現 我 跟本 用錯 方式
# 要 看 官網 教學 啊 ！
# 照 著 教學 方法 好 刷 很多
# 雖然 很 貴 但是 大 推 ！
# SUGAO 、 Air 、 Fit 、 空氣 CC霜 、
# 宮崎葵 好 可愛 啊 ( 大誤 )
# 這 款 被 好多 好多 網友 燒 到
# 腦殘 一
# 樣忘 了 買 （ 妳 到底 這次 買了 什麼 ）
# 總之 這麼 多 沒 買 到
# 就 可以 再 去 一次 日本 補貨 啦 （ 大大 誤 ） ！ 這裡 賣 一條 1380 <U + 5186 > ( 未 稅 )
# 武田合利他命 強效錠 EX 、 PLUS 、
# 至今 都 是 買 來 孝親 還 沒 自己 吃 過 ＠ ＠
# 下次 要 自己 入手 一罐 ＸＤ
# 這裡 賣 120顆/3600 <U + 5186 > ( 未 稅 ) ； 180 顆 / 5029<U + 5186 > ( 未 稅 ) ； 270 顆 / 5696 < U + 5186 > ( 未 稅 ) 。 （ 怎麼 看 都 要
# 買 270 顆 啊 、 !! ）
# KOSE 魔法 口紅 雨衣 、
# 其實 沒有 想像中 那麼 神奇
# 小動作 等等 比較 不 沾
# 但 你 有用 點 力 磨擦 其實 還是 一下 就 掉 了 。 這裡 賣 一支 1500 <U + 5186 > ( 未 稅 )
#
# MATSUGE 睫毛 美容 液 、
# 本人 睫毛 超 極 短
# 所以 很 愛 接 睫毛
# 之前 接 的 太 頻繁 斷裂 到 美睫師
# 都 叫 我 休息 ＠ ＠
# 擦 了 這個 之後 沒什麼 變 長 的 感覺 （ 我 也 沒 實際 去 量 啦 ）
# 但是 美睫師 有 說 我 的 睫毛 有 變強
# 壯惹
# 又 可以 繼續 接 睫毛 了 YA ！
# 這裡 賣 一支 1200 <U + 5186 > ( 未 稅 )
# 豆乳 優格 面膜 、
# 這 趟 來 日本 最 想 入手 的
# 聽說 敷完 臉 會 超嫩
# 太 想 買 的 東西 就 會 一直 以為 自己 買了
# 回到 台灣 發現 根本 沒 買 ....
# （ 這麼 多 沒 買 根本就是 命中注定 要 再 去 日本 ）
# 這裡 賣 一盒 1680 <U + 5186 > ( 未 稅 )
# ------------------------------
# 黑門市場 休息 區 ( KuRoMon 、 Information 、 Center )
# 逛街 逛累 了
# 黑門市場 還有 個 資訊站 可以 讓 大家 好好 休息
#
# 黑門市場 休息 區 ( KuRoMon 、 Information 、 Center ) (達村 商店 隔壁 )
# 地址 ： 大阪市 中央區 日本橋 2 - 12 - 22
# TEL ： 06 - 6631-0007
# FAX ： 06 - 6643-6464
# 營業 時間 、 ： 9:00 ～ 18:00
# 這裡 還有 提供 寄放 行李 的 服務
# 一天 500 <U + 5186 >
# 也 有 不同 語言 的 黑門市場 的 簡介
# 都 可以 免費 領取
# 這天 平日 來
# 休息 區 的 位子 就 只剩 一點點 >< 假日 可能 不要 抱 太大 期望 ＸＤ
# 等阿邦師 跟 老爸 去 上 廁所 的 時候
# 發現 旁邊 有 一整 排 扭蛋機 ！！
# 竟然 有 黃色 版 杯緣子耶
# 興致勃勃 的 準備 來 大 開 殺戒 ＸＤ
# 如果 日幣 沒 帶 夠
# 這邊 還有 可以 馬上 把 身上 的 外幣 換成 日幣 的 機器 ！！
# 口渴 了 這邊 還有 飲料 可以 買
# 不用 再 跑去 外面 便利商店 買 完 帶 進來 啦 ！
# 以上
# 就是 這次 黑門市場 的 小小 總 整理 啦 ！
# 如有 錯誤 歡迎 指教
# 會 盡快 更正 >< ' '
# 謝謝 大家 收看 !!
# --
# 艾咪 吃喝玩樂 愛 漂亮 推薦
# https : / / www.facebook . com/Amysjam
# http://tobbie0609.pixnet.net/blog
# --
# ※ 、 發信站 : 、 批踢踢 實業坊 ( ptt.cc ) , 、 來自 : 、 61.230.120.61
# ※ 、 文章 網址 : 、 https : / / www.ptt.cc/bbs/Japan _ Travel/M.1493711490.A.601.html
# 推 、 jordan1234 : 、 看完 內容 好 餓 呀 、 05/02 、 17:11
# 推 、 oaoastrid : 、 感覺 好玩 好吃耶 ( 默默 排到 行程 中 、 05/02 、 18:23
# 推 、 cloudie : 、 暑假 要 再 訪
# 感謝 整理 ！ 、 05/02 、 18:56
# 推 、 pontus : 、 謝謝 分享 、 05/02 、 22:42
# 噓 、 ap xd : 、 無聊 、 05/02 、 23:15
# 推 、 rugalex : 、 其實 黑門市場 真的 太多 觀光客 都會 去 了 、 特別 寫 一 篇 好像 也 、 05/03 、 01:52
# → 、 rugalex : 、 沒有 這麼 大 意義 就是 ....、05/03 、 01:52
# 推 、 racoon151 : 、 這樣 也 要 被 人 酸... ？ 謝謝 分享 、 05/04 、 00:17
# 推 、 pikapika425 : 、 謝謝 分享 心得 ~ 、 05/04 、 01:36
# 推 、 LoisLo : 、 推 用心 、 05/05 、 01:49
# 推 、 sdarks : 、 對 沒 去過 的 我 來說 值得 參考
# 謝謝 分享 、 05/05 、 12:42
# 推 、 johnnykuo 07 : 、 跟著 這樣 吃 就 對了 、 05 / 10 、 16:19
# ※ 、 編輯 : 、 chinchinyo 、 ( 118.167.49.51 ) ,、 05/11/2017 、 17:52:05
# "
# " x "

# %% [markdown]
# ### 從特定景點 tfidf 得到要用的詞，再從整體的tfidf 獲得分數

# %%
from sklearn.feature_extraction.text import CountVectorizer
tfidf_one_article_input=[]
three_dict=[]
for i in range(3):
    need_article=spotlist[i]
    for j in range(need_article.article[-1]):
        tfidf_one_article_input.append(" ".join(need_article.word[(need_article.article==j)*(get_str_tf(["a","n","nh","nf","nsf","v"],need_article))]))
    vectorizer1 =CountVectorizer()
    tfidf_article = vectorizer1.fit_transform(tfidf_one_article_input)
    articleword=np.array(vectorizer1.get_feature_names())
    tf_mat_article=tfidf_article.toarray()
    three_dict.append(create_dic(articleword[filter_ratio(tf_mat_article,0.01,1)],testword,tf_mat[i]))

# %%
three_dict[0]
# Out:
# {'12': 0.0024398538961786158,
#  '2018': 0.0024398538961786158,
#  '600yen': 0.004463069511187208,
#  'bbs': 0.09113306654349582,
#  'blog': 0.0015243665319698329,
#  'cc': 0.09113306654349582,
#  'com': 0.07545614333250672,
#  'cp值': 0.0048797077923572315,
#  'facebook': 0.01518884442391597,
#  'feel': 0.0024398538961786158,
#  'flickr': 0.037078061578488405,
#  'food': 0.041655315437747274,
#  'fubabytw': 0.0048797077923572315,
#  '想起': 0.0026477568102942542,
#  '愉悅': 0.0059507593482496105,
#  '意外': 0.006603845401702596,
#  '意志力': 0.0024398538961786158,
#  '意思': 0.003810916329924582,
#  '愛上': 0.004119784619832045,
#  '愛吃': 0.013238784051471272,
#  '愛好者': 0.0020598923099160223,
#  '愛知': 0.0029753796741248052,
#  '愜意': 0.001981153620510779,
#  '感到': 0.007319561688535848,
#  '感動': 0.00441292801715709,
#  '感受': 0.011886921723064672,
#  '感受到': 0.0017651712068628362,
#  '感想': 0.00823956923966409,
#  '感應': 0.0030898384648740335,
#  '感覺': 0.07198191487855829,
#  '感謝': 0.009245383562383634,
#  '態度': 0.00823956923966409,
#  '慕斯': 0.0020598923099160223,
#  '應該': 0.06075537769566388,
#  '懷念': 0.0048797077923572315,
#  '懷疑': 0.0017651712068628362,
#  '懷舊': 0.004119784619832045,
#  '成分': 0.003659780844267924,
#  '成功': 0.0015243665319698329,
#  '成為': 0.0026415381606810385,
#  '我會': 0.0052955136205885085,
#  '戰區': 0.004463069511187208,
#  '房家': 0.014419246169412156,
#  '房間': 0.0022865497979547493,
#  '所在': 0.0017651712068628362,
#  '所謂': 0.0035303424137256723,
#  '扁平': 0.0029753796741248052,
#  '扇貝': 0.00609963474044654,
#  '手作': 0.003659780844267924,
#  '手工': 0.0030898384648740335,
#  '手帖': 0.0048797077923572315,
#  '手機': 0.003962307241021558,
#  '手殘': 0.0029753796741248052,
#  '手藝': 0.0029753796741248052,
#  '才是': 0.0029753796741248052,
#  '才能': 0.006603845401702596,
#  '扎實': 0.0029753796741248052,
#  '打入': 0.0029753796741248052,
#  '打卡': 0.0035303424137256723,
#  '打算': 0.001981153620510779,
#  '打錯': 0.0024398538961786158,
#  '打開': 0.009908382457803913,
#  '批踢踢': 0.10830306458792258,
#  '找不到': 0.0017651712068628362,
#  '找到': 0.019151151664937527,
#  '找尋': 0.0017651712068628362,
#  '技術': 0.0015243665319698329,
#  '抱著': 0.0020598923099160223,
#  '抵達': 0.012547306263234932,
#  '抹上': 0.004463069511187208,
#  '抹茶': 0.031249513905381575,
#  ...}

# %%
temp_dic["藥妝"]
# Out:
# 0.03544778529881435

# %% [markdown]
# ### 類似景點 tfidf 類似程度

# %% [markdown]
# ## 整體tfidf

# %%
tfidf_input=[]
for i ,j in zip(spotlist,range(len(spotlist))):
    try:
        tfidf_input.append(get_str(["a","n","nh","nf","nsf","v"],i))
    except:
        tfidf_input.append("ng ng ng")
        print(dirs[j])
vectorizer = TfidfVectorizer()     
tfidf = vectorizer.fit_transform(tfidf_input)
testword=np.array(vectorizer.get_feature_names())
tf_mat=tfidf.toarray()

# %%
print((np.argsort(tf_mat[1])))
print(type(testword))
# Out:
# [18703  8172  8173 ...  9417  4340  6914]
# <class 'numpy.ndarray'>

# %%
def show_top_word(tf,top_n,testword_):
    _testword_=np.array(testword_)
    print(_testword_[np.flip(np.argsort(tf),0)][0:top_n])
show_top_word(tf_mat[1],200,testword)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-3eacbb76dc9f> in <module>()
#       2     _testword_=np.array(testword_)
#       3     print(_testword_[np.flip(np.argsort(tf),0)][0:top_n])
# ----> 4 show_top_word(tf_mat[1],200,testword)
#
# NameError: name 'tf_mat' is not defined

# %% [markdown]
# __[blog_排組](https://www.cnblogs.com/alexkh/archive/2013/03/20/2971533.html)__

# %%
test=spot_tfidf(tf_mat,testword,dirs)
need_=test.filter_ratio(0.01,1)
test.mat=test.mat[:,need_]
test.word=test.word[need_]

# %%
test.mat.shape
# Out:
# (505, 16877)

# %%
"""import pandas as pd 
df = pd.DataFrame(test.mat)
df.to_csv("D:/data/final_project/mat.csv",header=None,index=False)
df = pd.DataFrame(test.word)
df.to_csv("D:/data/final_project/word.csv",header=None,index=False)
df = pd.DataFrame(np.array(dirs))
df.to_csv("D:/data/final_project/spot.csv",header=None,index=False)"""

# %%
show_top_word(test.most_similar(test.spword_tf(["世豊商店.txt","合羽橋道具街 .txt","巢鴨地藏通商店街 .txt"])),30,dirs)
# Out:
# ['千日前道具屋筋商店街.txt' '京都御苑.txt' '大須觀音.txt' '合羽橋道具街 .txt' '水鏡天滿宮 .txt'
#  '心齋橋筋商店街.txt' '新京極商店街.txt' '東京站一番街 .txt' '天神橋筋商店街.txt' '戎橋.txt'
#  '神戶港塔 .txt' '巢鴨地藏通商店街 .txt' '橫濱元町商店街.txt' '大須商店街.txt' '吉祥寺.txt'
#  '大阪生活今昔館 .txt' '原宿.txt' '三宮中心街 .txt' '阿美橫丁 .txt' '輕井澤王子outlet .txt'
#  '臨空城Outlet .txt' '增上寺 .txt' '狸小路.txt' '免稅店DFS.txt' '道頓堀水上觀光船.txt'
#  '仲見世通.txt' '常寂光寺.txt' '四條河原町.txt' '御殿場 Premium Outlet .txt' '阿蘇神社.txt']

# %%
show_top_word(test.most_similar(test.spword_tf(["根津神社.txt","北海道神宮.txt","上賀茂神社.txt","八坂神社.txt","出雲大社.txt"],batch=4)),30,dirs)
# Out:
# ['川越冰川神社 .txt' '靖國神社 .txt' '上賀茂神社.txt' '下鴨神社.txt' '八坂神社.txt' '根津神社.txt'
#  '嚴島神社 .txt' '平野神社.txt' '神樂坂.txt' '宮島.txt' '淺草神社 .txt' '櫛田神社.txt'
#  '晴明神社.txt' '冰室神社 .txt' '千本鳥居.txt' '地主神社.txt' '伏見稻荷大社.txt' '千鳥之淵 .txt'
#  '波上宮.txt' '水前寺成趣園.txt' '出雲大社.txt' '高千穗峽 .txt' '鬼之洗濯板 .txt' '江之島 .txt'
#  '貴船神社.txt' '清水寺.txt' '野宮神社.txt' '祇園.txt' '圓山公園 .txt' '難波八阪神社.txt']

# %%
show_top_word(test.most_similar(test.spword_tf(["層雲峽 .txt","十和田湖.txt","嵐山.txt","摩周湖.txt"],batch=2)),30,dirs)
# Out:
# ['華嚴瀑布 .txt' '層雲峽 .txt' '中禪寺湖 .txt' '十和田湖.txt' '白絲瀑布 .txt' '奧入瀨溪 .txt'
#  '京都御苑.txt' '草津溫泉 .txt' '水鏡天滿宮 .txt' '常寂光寺.txt' '白鬚瀑布 .txt' '銀山溫泉 .txt'
#  '八甲田山.txt' '知床五湖.txt' '高千穗峽 .txt' '永觀堂.txt' '霧島神宮.txt' '道後溫泉 .txt'
#  '御殿場 Premium Outlet .txt' '定山溪 .txt' '別府地獄.txt' '河口湖.txt' '金閣寺.txt'
#  '摩周湖.txt' '高尾山.txt' '嵐山.txt' '二荒山神社.txt' '青池 .txt' '雪之大谷 .txt' '上高地.txt']

# %%
"""with open("./data/newword.txt","r",encoding="utf8") as file:
    temps=file.read()
    temps=temps.replace("\t"," ")
    temps=temps.replace("  "," ")
    addlist=temps.split("\n")
#addlist=["道敦堀 nsf"]#自定新词
spot=[]
for i in addlist:    
    k=i.split(" ")
    spot.append(k[0])
spot"""
# Out:
# 'with open("./data/newword.txt","r",encoding="utf8") as file:\n    temps=file.read()\n    temps=temps.replace("\t"," ")\n    temps=temps.replace("  "," ")\n    addlist=temps.split("\n")\n#addlist=["道敦堀 nsf"]#自定新词\nspot=[]\nfor i in addlist:    \n    k=i.split(" ")\n    spot.append(k[0])\nspot'

# %%
l=1
name="a"
newtxtlist=[]
for i in range(1,l+1):
    with open("./data/article/"+str(name)+" ("+str(i)+").txt","r",encoding="utf8") as file:
        newtxtlist.append(decode_txt(file.read()))

# %%
class singleword:
    def __init__(self,L):
        self.word=L[0]
        self.id=L[1]
        self.type=L[2]
        self.pword=L[5]
        self.linktype=L[3]
        self.tag=[]
    def show(self):
        print(self.word,self.type,self.index,"  ",self.pword,self.linktype,self.tag)
    def setindex(self,p):
        self.index=p

# %%
newtxtlist
# Out:
# [[<__main__.singleword at 0x1d4e54a8860>,
#   <__main__.singleword at 0x1d4e54a87f0>,
#   <__main__.singleword at 0x1d4e54a8940>,
#   <__main__.singleword at 0x1d4e54a89e8>,
#   <__main__.singleword at 0x1d4e54a8a90>,
#   <__main__.singleword at 0x1d4e54a8b00>,
#   <__main__.singleword at 0x1d4e54a8ba8>,
#   <__main__.singleword at 0x1d4e54a8c50>,
#   <__main__.singleword at 0x1d4e54a8cf8>,
#   <__main__.singleword at 0x1d4e54a8da0>,
#   <__main__.singleword at 0x1d4e54a8e80>,
#   <__main__.singleword at 0x1d4e54a8f28>,
#   <__main__.singleword at 0x1d4e526f048>,
#   <__main__.singleword at 0x1d4e526f160>,
#   <__main__.singleword at 0x1d4e526f278>,
#   <__main__.singleword at 0x1d4e526f3c8>,
#   <__main__.singleword at 0x1d4e526f390>,
#   <__main__.singleword at 0x1d4e526f550>,
#   <__main__.singleword at 0x1d4e526f630>,
#   <__main__.singleword at 0x1d4e526f710>,
#   <__main__.singleword at 0x1d4e526f7f0>,
#   <__main__.singleword at 0x1d4e526f908>,
#   <__main__.singleword at 0x1d4e526f8d0>,
#   <__main__.singleword at 0x1d4e526fac8>,
#   <__main__.singleword at 0x1d4e526fba8>,
#   <__main__.singleword at 0x1d4e526fc88>,
#   <__main__.singleword at 0x1d4e526fd68>,
#   <__main__.singleword at 0x1d4e526fe80>,
#   <__main__.singleword at 0x1d4e526ff60>,
#   <__main__.singleword at 0x1d4e52770b8>,
#   <__main__.singleword at 0x1d4e5277198>,
#   <__main__.singleword at 0x1d4e5277278>,
#   <__main__.singleword at 0x1d4e5277358>,
#   <__main__.singleword at 0x1d4e5277438>,
#   <__main__.singleword at 0x1d4e5277518>,
#   <__main__.singleword at 0x1d4e52775f8>,
#   <__main__.singleword at 0x1d4e5277710>,
#   <__main__.singleword at 0x1d4e52777f0>,
#   <__main__.singleword at 0x1d4e52778d0>,
#   <__main__.singleword at 0x1d4e52779b0>,
#   <__main__.singleword at 0x1d4e5277a90>,
#   <__main__.singleword at 0x1d4e5277b70>,
#   <__main__.singleword at 0x1d4e5277c50>,
#   <__main__.singleword at 0x1d4e5277d68>,
#   <__main__.singleword at 0x1d4e5277e48>,
#   <__main__.singleword at 0x1d4e5277f28>,
#   <__main__.singleword at 0x1d4e526c048>,
#   <__main__.singleword at 0x1d4e526c128>,
#   <__main__.singleword at 0x1d4e526c208>,
#   <__main__.singleword at 0x1d4e526c2e8>,
#   <__main__.singleword at 0x1d4e526c3c8>,
#   <__main__.singleword at 0x1d4e526c4e0>,
#   <__main__.singleword at 0x1d4e526c5c0>,
#   <__main__.singleword at 0x1d4e526c6a0>,
#   <__main__.singleword at 0x1d4e526c780>,
#   <__main__.singleword at 0x1d4e526c860>,
#   <__main__.singleword at 0x1d4e526c940>,
#   <__main__.singleword at 0x1d4e526ca20>,
#   <__main__.singleword at 0x1d4e526cb38>,
#   <__main__.singleword at 0x1d4e526cc18>,
#   <__main__.singleword at 0x1d4e526ccf8>,
#   <__main__.singleword at 0x1d4e526cdd8>,
#   <__main__.singleword at 0x1d4e526cef0>,
#   <__main__.singleword at 0x1d4e526cfd0>,
#   <__main__.singleword at 0x1d4e52760f0>,
#   <__main__.singleword at 0x1d4e52761d0>,
#   <__main__.singleword at 0x1d4e52762b0>,
#   <__main__.singleword at 0x1d4e52763c8>,
#   <__main__.singleword at 0x1d4e5276390>,
#   <__main__.singleword at 0x1d4e5276588>,
#   <__main__.singleword at 0x1d4e5276668>,
#   <__main__.singleword at 0x1d4e5276780>,
#   <__main__.singleword at 0x1d4e5276860>,
#   <__main__.singleword at 0x1d4e5276940>,
#   <__main__.singleword at 0x1d4e5276a58>,
#   <__main__.singleword at 0x1d4e5276b38>,
#   <__main__.singleword at 0x1d4e5276c50>,
#   <__main__.singleword at 0x1d4e5276d30>,
#   <__main__.singleword at 0x1d4e5276e48>,
#   <__main__.singleword at 0x1d4e5276f28>,
#   <__main__.singleword at 0x1d4e528e048>,
#   <__main__.singleword at 0x1d4e528e160>,
#   <__main__.singleword at 0x1d4e528e128>,
#   <__main__.singleword at 0x1d4e528e358>,
#   <__main__.singleword at 0x1d4e528e438>,
#   <__main__.singleword at 0x1d4e528e588>,
#   <__main__.singleword at 0x1d4e528e6d8>,
#   <__main__.singleword at 0x1d4e528e6a0>,
#   <__main__.singleword at 0x1d4e528e7f0>,
#   <__main__.singleword at 0x1d4e528e9b0>,
#   <__main__.singleword at 0x1d4e528ea90>,
#   <__main__.singleword at 0x1d4e528eb70>,
#   <__main__.singleword at 0x1d4e528ec50>,
#   <__main__.singleword at 0x1d4e528ed68>,
#   <__main__.singleword at 0x1d4e528ee48>,
#   <__main__.singleword at 0x1d4e528ef28>,
#   <__main__.singleword at 0x1d4e526e080>,
#   <__main__.singleword at 0x1d4e526e198>,
#   <__main__.singleword at 0x1d4e526e160>,
#   <__main__.singleword at 0x1d4e526e320>,
#   <__main__.singleword at 0x1d4e526e400>,
#   <__main__.singleword at 0x1d4e526e4e0>,
#   <__main__.singleword at 0x1d4e526e5c0>,
#   <__main__.singleword at 0x1d4e526e6a0>,
#   <__main__.singleword at 0x1d4e526e7f0>,
#   <__main__.singleword at 0x1d4e526e8d0>,
#   <__main__.singleword at 0x1d4e526e9e8>,
#   <__main__.singleword at 0x1d4e526e9b0>,
#   <__main__.singleword at 0x1d4e526eba8>,
#   <__main__.singleword at 0x1d4e526ec88>,
#   <__main__.singleword at 0x1d4e526eda0>,
#   <__main__.singleword at 0x1d4e526ee80>,
#   <__main__.singleword at 0x1d4e526ef60>,
#   <__main__.singleword at 0x1d4e529f080>,
#   <__main__.singleword at 0x1d4e529f198>,
#   <__main__.singleword at 0x1d4e529f278>,
#   <__main__.singleword at 0x1d4e529f390>,
#   <__main__.singleword at 0x1d4e529f4e0>,
#   <__main__.singleword at 0x1d4e529f5c0>,
#   <__main__.singleword at 0x1d4e529f6a0>,
#   <__main__.singleword at 0x1d4e529f780>,
#   <__main__.singleword at 0x1d4e529f898>,
#   <__main__.singleword at 0x1d4e529f860>,
#   <__main__.singleword at 0x1d4e529fa58>,
#   <__main__.singleword at 0x1d4e529fa20>,
#   <__main__.singleword at 0x1d4e529fb38>,
#   <__main__.singleword at 0x1d4e529fcc0>,
#   <__main__.singleword at 0x1d4e529fdd8>,
#   <__main__.singleword at 0x1d4e529fef0>,
#   <__main__.singleword at 0x1d4e529ffd0>,
#   <__main__.singleword at 0x1d4e52880f0>,
#   <__main__.singleword at 0x1d4e52881d0>,
#   <__main__.singleword at 0x1d4e52882b0>,
#   <__main__.singleword at 0x1d4e5288390>,
#   <__main__.singleword at 0x1d4e5288470>,
#   <__main__.singleword at 0x1d4e5288550>,
#   <__main__.singleword at 0x1d4e5288668>,
#   <__main__.singleword at 0x1d4e5288748>,
#   <__main__.singleword at 0x1d4e5288828>,
#   <__main__.singleword at 0x1d4e5288908>,
#   <__main__.singleword at 0x1d4e52889e8>,
#   <__main__.singleword at 0x1d4e5288ac8>,
#   <__main__.singleword at 0x1d4e5288ba8>,
#   <__main__.singleword at 0x1d4e5288c88>,
#   <__main__.singleword at 0x1d4e5288d68>,
#   <__main__.singleword at 0x1d4e5288e48>,
#   <__main__.singleword at 0x1d4e5288f28>,
#   <__main__.singleword at 0x1d4e528a048>,
#   <__main__.singleword at 0x1d4e528a128>,
#   <__main__.singleword at 0x1d4e528a208>,
#   <__main__.singleword at 0x1d4e528a2e8>,
#   <__main__.singleword at 0x1d4e528a3c8>,
#   <__main__.singleword at 0x1d4e528a4a8>,
#   <__main__.singleword at 0x1d4e528a588>,
#   <__main__.singleword at 0x1d4e528a6a0>,
#   <__main__.singleword at 0x1d4e528a780>,
#   <__main__.singleword at 0x1d4e528a898>,
#   <__main__.singleword at 0x1d4e528a978>,
#   <__main__.singleword at 0x1d4e528aa58>,
#   <__main__.singleword at 0x1d4e528ab38>,
#   <__main__.singleword at 0x1d4e528ac50>,
#   <__main__.singleword at 0x1d4e528ad30>,
#   <__main__.singleword at 0x1d4e528ae10>,
#   <__main__.singleword at 0x1d4e528aef0>,
#   <__main__.singleword at 0x1d4e528afd0>,
#   <__main__.singleword at 0x1d4e52930f0>,
#   <__main__.singleword at 0x1d4e52931d0>,
#   <__main__.singleword at 0x1d4e5293320>,
#   <__main__.singleword at 0x1d4e5293400>,
#   <__main__.singleword at 0x1d4e5293518>,
#   <__main__.singleword at 0x1d4e52935f8>,
#   <__main__.singleword at 0x1d4e5293710>,
#   <__main__.singleword at 0x1d4e52937f0>,
#   <__main__.singleword at 0x1d4e52938d0>,
#   <__main__.singleword at 0x1d4e52939b0>,
#   <__main__.singleword at 0x1d4e5293a90>,
#   <__main__.singleword at 0x1d4e5293b70>,
#   <__main__.singleword at 0x1d4e5293c50>,
#   <__main__.singleword at 0x1d4e5293d30>,
#   <__main__.singleword at 0x1d4e5293e48>,
#   <__main__.singleword at 0x1d4e5293f28>,
#   <__main__.singleword at 0x1d4e528b048>,
#   <__main__.singleword at 0x1d4e528b128>,
#   <__main__.singleword at 0x1d4e528b208>,
#   <__main__.singleword at 0x1d4e528b2e8>,
#   <__main__.singleword at 0x1d4e528b3c8>,
#   <__main__.singleword at 0x1d4e528b4a8>,
#   <__main__.singleword at 0x1d4e528b588>,
#   <__main__.singleword at 0x1d4e528b6a0>,
#   <__main__.singleword at 0x1d4e528b780>,
#   <__main__.singleword at 0x1d4e528b8d0>,
#   <__main__.singleword at 0x1d4e528b978>,
#   <__main__.singleword at 0x1d4e528ba90>,
#   <__main__.singleword at 0x1d4e528bba8>,
#   <__main__.singleword at 0x1d4e528bc88>,
#   <__main__.singleword at 0x1d4e528bd68>,
#   <__main__.singleword at 0x1d4e528be80>,
#   <__main__.singleword at 0x1d4e528bf60>,
#   <__main__.singleword at 0x1d4e527c0f0>,
#   <__main__.singleword at 0x1d4e527c1d0>,
#   <__main__.singleword at 0x1d4e527c2b0>,
#   <__main__.singleword at 0x1d4e527c390>,
#   <__main__.singleword at 0x1d4e527c470>,
#   <__main__.singleword at 0x1d4e527c588>,
#   <__main__.singleword at 0x1d4e527c668>,
#   <__main__.singleword at 0x1d4e527c780>,
#   <__main__.singleword at 0x1d4e527c748>,
#   <__main__.singleword at 0x1d4e527c860>,
#   <__main__.singleword at 0x1d4e527c940>,
#   <__main__.singleword at 0x1d4e527ca20>,
#   <__main__.singleword at 0x1d4e527cb00>,
#   <__main__.singleword at 0x1d4e527cbe0>,
#   <__main__.singleword at 0x1d4e527ccc0>,
#   <__main__.singleword at 0x1d4e527cda0>,
#   <__main__.singleword at 0x1d4e527cfd0>,
#   <__main__.singleword at 0x1d4e527cf98>,
#   <__main__.singleword at 0x1d4e65f50f0>,
#   <__main__.singleword at 0x1d4e65f51d0>,
#   <__main__.singleword at 0x1d4e65f52b0>,
#   <__main__.singleword at 0x1d4e65f5390>,
#   <__main__.singleword at 0x1d4e65f5470>,
#   <__main__.singleword at 0x1d4e65f5550>,
#   <__main__.singleword at 0x1d4e65f5630>,
#   <__main__.singleword at 0x1d4e65f5710>,
#   <__main__.singleword at 0x1d4e65f57f0>,
#   <__main__.singleword at 0x1d4e65f58d0>,
#   <__main__.singleword at 0x1d4e65f59b0>,
#   <__main__.singleword at 0x1d4e65f5a90>,
#   <__main__.singleword at 0x1d4e65f5ba8>,
#   <__main__.singleword at 0x1d4e65f5c88>,
#   <__main__.singleword at 0x1d4e65f5d68>,
#   <__main__.singleword at 0x1d4e65f5e48>,
#   <__main__.singleword at 0x1d4e65f5f28>,
#   <__main__.singleword at 0x1d4e65ee048>,
#   <__main__.singleword at 0x1d4e65ee160>,
#   <__main__.singleword at 0x1d4e65ee240>,
#   <__main__.singleword at 0x1d4e65ee358>,
#   <__main__.singleword at 0x1d4e65ee438>,
#   <__main__.singleword at 0x1d4e65ee518>,
#   <__main__.singleword at 0x1d4e65ee5f8>,
#   <__main__.singleword at 0x1d4e65ee6d8>,
#   <__main__.singleword at 0x1d4e65ee7b8>,
#   <__main__.singleword at 0x1d4e65ee898>,
#   <__main__.singleword at 0x1d4e65ee978>,
#   <__main__.singleword at 0x1d4e65eea58>,
#   <__main__.singleword at 0x1d4e65eeb38>,
#   <__main__.singleword at 0x1d4e65eec18>,
#   <__main__.singleword at 0x1d4e65eecf8>,
#   <__main__.singleword at 0x1d4e65eedd8>,
#   <__main__.singleword at 0x1d4e65eeef0>,
#   <__main__.singleword at 0x1d4e65eeeb8>,
#   <__main__.singleword at 0x1d4e65ed0f0>,
#   <__main__.singleword at 0x1d4e65ed208>,
#   <__main__.singleword at 0x1d4e65ed2e8>,
#   <__main__.singleword at 0x1d4e65ed400>,
#   <__main__.singleword at 0x1d4e65ed518>,
#   <__main__.singleword at 0x1d4e65ed4e0>,
#   <__main__.singleword at 0x1d4e65ed6d8>,
#   <__main__.singleword at 0x1d4e65ed7b8>,
#   <__main__.singleword at 0x1d4e65ed8d0>,
#   <__main__.singleword at 0x1d4e65ed9b0>,
#   <__main__.singleword at 0x1d4e65eda90>,
#   <__main__.singleword at 0x1d4e65edb70>,
#   <__main__.singleword at 0x1d4e65edc50>,
#   <__main__.singleword at 0x1d4e65edd30>,
#   <__main__.singleword at 0x1d4e65ede10>,
#   <__main__.singleword at 0x1d4e65edef0>,
#   <__main__.singleword at 0x1d4e65edfd0>,
#   <__main__.singleword at 0x1d4e65e70f0>,
#   <__main__.singleword at 0x1d4e65e7208>,
#   <__main__.singleword at 0x1d4e65e72e8>,
#   <__main__.singleword at 0x1d4e65e73c8>,
#   <__main__.singleword at 0x1d4e65e74a8>,
#   <__main__.singleword at 0x1d4e65e7588>,
#   <__main__.singleword at 0x1d4e65e7668>,
#   <__main__.singleword at 0x1d4e65e7748>,
#   <__main__.singleword at 0x1d4e65e7828>,
#   <__main__.singleword at 0x1d4e65e7940>,
#   <__main__.singleword at 0x1d4e65e7a20>,
#   <__main__.singleword at 0x1d4e65e7b00>,
#   <__main__.singleword at 0x1d4e65e7c18>,
#   <__main__.singleword at 0x1d4e65e7cf8>,
#   <__main__.singleword at 0x1d4e65e7e10>,
#   <__main__.singleword at 0x1d4e65e7ef0>,
#   <__main__.singleword at 0x1d4e65f4048>,
#   <__main__.singleword at 0x1d4e65f4128>,
#   <__main__.singleword at 0x1d4e65f4208>,
#   <__main__.singleword at 0x1d4e65f4320>,
#   <__main__.singleword at 0x1d4e65f4400>,
#   <__main__.singleword at 0x1d4e65f44e0>,
#   <__main__.singleword at 0x1d4e65f45c0>,
#   <__main__.singleword at 0x1d4e65f46a0>,
#   <__main__.singleword at 0x1d4e65f4780>,
#   <__main__.singleword at 0x1d4e65f4860>,
#   <__main__.singleword at 0x1d4e65f4940>,
#   <__main__.singleword at 0x1d4e65f4a20>,
#   <__main__.singleword at 0x1d4e65f4b00>,
#   <__main__.singleword at 0x1d4e65f4be0>,
#   <__main__.singleword at 0x1d4e65f4cc0>,
#   <__main__.singleword at 0x1d4e65f4da0>,
#   <__main__.singleword at 0x1d4e65f4e80>,
#   <__main__.singleword at 0x1d4e65f4f60>,
#   <__main__.singleword at 0x1d4e65d9080>,
#   <__main__.singleword at 0x1d4e65d9198>,
#   <__main__.singleword at 0x1d4e65d9278>,
#   <__main__.singleword at 0x1d4e65d9358>,
#   <__main__.singleword at 0x1d4e65d9438>,
#   <__main__.singleword at 0x1d4e65d9518>,
#   <__main__.singleword at 0x1d4e65d95f8>,
#   <__main__.singleword at 0x1d4e65d96d8>,
#   <__main__.singleword at 0x1d4e65d97b8>,
#   <__main__.singleword at 0x1d4e65d98d0>,
#   <__main__.singleword at 0x1d4e65d99b0>,
#   <__main__.singleword at 0x1d4e65d9a90>,
#   <__main__.singleword at 0x1d4e65d9b70>,
#   <__main__.singleword at 0x1d4e65d9c50>,
#   <__main__.singleword at 0x1d4e65d9d30>,
#   <__main__.singleword at 0x1d4e65d9e10>,
#   <__main__.singleword at 0x1d4e65d9ef0>,
#   <__main__.singleword at 0x1d4e65d9fd0>,
#   <__main__.singleword at 0x1d4e65d30f0>,
#   <__main__.singleword at 0x1d4e65d31d0>,
#   <__main__.singleword at 0x1d4e65d32b0>,
#   <__main__.singleword at 0x1d4e65d3390>,
#   <__main__.singleword at 0x1d4e65d34a8>,
#   <__main__.singleword at 0x1d4e65d3588>,
#   <__main__.singleword at 0x1d4e65d3668>,
#   <__main__.singleword at 0x1d4e65d3748>,
#   <__main__.singleword at 0x1d4e65d3828>,
#   <__main__.singleword at 0x1d4e65d3908>,
#   <__main__.singleword at 0x1d4e65d39e8>,
#   <__main__.singleword at 0x1d4e65d3ac8>,
#   <__main__.singleword at 0x1d4e65d3ba8>,
#   <__main__.singleword at 0x1d4e65d3c88>,
#   <__main__.singleword at 0x1d4e65d3d68>,
#   <__main__.singleword at 0x1d4e65d3e48>,
#   <__main__.singleword at 0x1d4e65d3f28>,
#   <__main__.singleword at 0x1d4e65f1048>,
#   <__main__.singleword at 0x1d4e65f1128>,
#   <__main__.singleword at 0x1d4e65f1208>,
#   <__main__.singleword at 0x1d4e65f1320>,
#   <__main__.singleword at 0x1d4e65f1400>,
#   <__main__.singleword at 0x1d4e65f14e0>,
#   <__main__.singleword at 0x1d4e65f15f8>,
#   <__main__.singleword at 0x1d4e65f16d8>,
#   <__main__.singleword at 0x1d4e65f17b8>,
#   <__main__.singleword at 0x1d4e65f1898>,
#   <__main__.singleword at 0x1d4e65f1978>,
#   <__main__.singleword at 0x1d4e65f1a90>,
#   <__main__.singleword at 0x1d4e65f1a58>,
#   <__main__.singleword at 0x1d4e65f1c50>,
#   <__main__.singleword at 0x1d4e65f1d30>,
#   <__main__.singleword at 0x1d4e65f1e48>,
#   <__main__.singleword at 0x1d4e65f1f60>,
#   <__main__.singleword at 0x1d4e65f1f28>,
#   <__main__.singleword at 0x1d4e65fc160>,
#   <__main__.singleword at 0x1d4e65fc240>,
#   <__main__.singleword at 0x1d4e65fc358>,
#   <__main__.singleword at 0x1d4e65fc438>,
#   <__main__.singleword at 0x1d4e65fc518>,
#   <__main__.singleword at 0x1d4e65fc5f8>,
#   <__main__.singleword at 0x1d4e65fc710>,
#   <__main__.singleword at 0x1d4e65fc7f0>,
#   <__main__.singleword at 0x1d4e65fc908>,
#   <__main__.singleword at 0x1d4e65fca20>,
#   <__main__.singleword at 0x1d4e65fcb00>,
#   <__main__.singleword at 0x1d4e65fcc18>,
#   <__main__.singleword at 0x1d4e65fccf8>,
#   <__main__.singleword at 0x1d4e65fcdd8>,
#   <__main__.singleword at 0x1d4e65fceb8>,
#   <__main__.singleword at 0x1d4e65fcf98>,
#   <__main__.singleword at 0x1d4e65d50b8>,
#   <__main__.singleword at 0x1d4e65d51d0>,
#   <__main__.singleword at 0x1d4e65d52b0>,
#   <__main__.singleword at 0x1d4e65d5390>,
#   <__main__.singleword at 0x1d4e65d5470>,
#   <__main__.singleword at 0x1d4e65d5550>,
#   <__main__.singleword at 0x1d4e65d5630>,
#   <__main__.singleword at 0x1d4e65d5748>,
#   <__main__.singleword at 0x1d4e65d5828>,
#   <__main__.singleword at 0x1d4e65d5908>,
#   <__main__.singleword at 0x1d4e65d5a20>,
#   <__main__.singleword at 0x1d4e65d5b38>,
#   <__main__.singleword at 0x1d4e65d5b00>,
#   <__main__.singleword at 0x1d4e65d5d68>,
#   <__main__.singleword at 0x1d4e65d5d30>,
#   <__main__.singleword at 0x1d4e65d5ef0>,
#   <__main__.singleword at 0x1d4e65d5fd0>,
#   <__main__.singleword at 0x1d4e65f30f0>,
#   <__main__.singleword at 0x1d4e65f31d0>,
#   <__main__.singleword at 0x1d4e65f3320>,
#   <__main__.singleword at 0x1d4e65f32e8>,
#   <__main__.singleword at 0x1d4e65f3518>,
#   <__main__.singleword at 0x1d4e65f34e0>,
#   <__main__.singleword at 0x1d4e65f36d8>,
#   <__main__.singleword at 0x1d4e65f37f0>,
#   <__main__.singleword at 0x1d4e65f3908>,
#   <__main__.singleword at 0x1d4e65f39e8>,
#   <__main__.singleword at 0x1d4e65f3ac8>,
#   <__main__.singleword at 0x1d4e65f3be0>,
#   <__main__.singleword at 0x1d4e65f3cf8>,
#   <__main__.singleword at 0x1d4e65f3dd8>,
#   <__main__.singleword at 0x1d4e65f3ef0>,
#   <__main__.singleword at 0x1d4e65f3fd0>,
#   <__main__.singleword at 0x1d4e65db0f0>,
#   <__main__.singleword at 0x1d4e65db208>,
#   <__main__.singleword at 0x1d4e65db2e8>,
#   <__main__.singleword at 0x1d4e65db3c8>,
#   <__main__.singleword at 0x1d4e65db4e0>,
#   <__main__.singleword at 0x1d4e65db5c0>,
#   <__main__.singleword at 0x1d4e65db6d8>,
#   <__main__.singleword at 0x1d4e65db7b8>,
#   <__main__.singleword at 0x1d4e65db8d0>,
#   <__main__.singleword at 0x1d4e65db9b0>,
#   <__main__.singleword at 0x1d4e65dba90>,
#   <__main__.singleword at 0x1d4e65dbb70>,
#   <__main__.singleword at 0x1d4e65dbc50>,
#   <__main__.singleword at 0x1d4e65dbd30>,
#   <__main__.singleword at 0x1d4e65dbe48>,
#   <__main__.singleword at 0x1d4e65dbf60>,
#   <__main__.singleword at 0x1d4e65d8080>,
#   <__main__.singleword at 0x1d4e65d8160>,
#   <__main__.singleword at 0x1d4e65d8240>,
#   <__main__.singleword at 0x1d4e65d8320>,
#   <__main__.singleword at 0x1d4e65d8438>,
#   <__main__.singleword at 0x1d4e65d8518>,
#   <__main__.singleword at 0x1d4e65d85f8>,
#   <__main__.singleword at 0x1d4e65d86d8>,
#   <__main__.singleword at 0x1d4e65d87b8>,
#   <__main__.singleword at 0x1d4e65d8898>,
#   <__main__.singleword at 0x1d4e65d89b0>,
#   <__main__.singleword at 0x1d4e65d8b00>,
#   <__main__.singleword at 0x1d4e65d8ac8>,
#   <__main__.singleword at 0x1d4e65d8c88>,
#   <__main__.singleword at 0x1d4e65d8d68>,
#   <__main__.singleword at 0x1d4e65d8e48>,
#   <__main__.singleword at 0x1d4e65d8f28>,
#   <__main__.singleword at 0x1d4e6602080>,
#   <__main__.singleword at 0x1d4e6602160>,
#   <__main__.singleword at 0x1d4e6602240>,
#   <__main__.singleword at 0x1d4e6602320>,
#   <__main__.singleword at 0x1d4e6602400>,
#   <__main__.singleword at 0x1d4e66024e0>,
#   <__main__.singleword at 0x1d4e66025c0>,
#   <__main__.singleword at 0x1d4e66026a0>,
#   <__main__.singleword at 0x1d4e66027b8>,
#   <__main__.singleword at 0x1d4e6602898>,
#   <__main__.singleword at 0x1d4e6602978>,
#   <__main__.singleword at 0x1d4e6602a58>,
#   <__main__.singleword at 0x1d4e6602b38>,
#   <__main__.singleword at 0x1d4e6602c50>,
#   <__main__.singleword at 0x1d4e6602d30>,
#   <__main__.singleword at 0x1d4e6602e10>,
#   <__main__.singleword at 0x1d4e6602ef0>,
#   <__main__.singleword at 0x1d4e6602fd0>,
#   <__main__.singleword at 0x1d4e65eb0f0>,
#   <__main__.singleword at 0x1d4e65eb1d0>,
#   <__main__.singleword at 0x1d4e65eb2b0>,
#   <__main__.singleword at 0x1d4e65eb390>,
#   <__main__.singleword at 0x1d4e65eb470>,
#   <__main__.singleword at 0x1d4e65eb550>,
#   <__main__.singleword at 0x1d4e65eb630>,
#   <__main__.singleword at 0x1d4e65eb748>,
#   <__main__.singleword at 0x1d4e65eb828>,
#   <__main__.singleword at 0x1d4e65eb908>,
#   <__main__.singleword at 0x1d4e65eba20>,
#   <__main__.singleword at 0x1d4e65ebb38>,
#   <__main__.singleword at 0x1d4e65ebb00>,
#   <__main__.singleword at 0x1d4e65ebcc0>,
#   <__main__.singleword at 0x1d4e65ebda0>,
#   <__main__.singleword at 0x1d4e65ebe80>,
#   <__main__.singleword at 0x1d4e65ebf60>,
#   <__main__.singleword at 0x1d4e65ea080>,
#   <__main__.singleword at 0x1d4e65ea160>,
#   <__main__.singleword at 0x1d4e65ea240>,
#   <__main__.singleword at 0x1d4e65ea320>,
#   <__main__.singleword at 0x1d4e65ea470>,
#   <__main__.singleword at 0x1d4e65ea438>,
#   <__main__.singleword at 0x1d4e65ea588>,
#   <__main__.singleword at 0x1d4e65ea748>,
#   <__main__.singleword at 0x1d4e65ea828>,
#   <__main__.singleword at 0x1d4e65ea940>,
#   <__main__.singleword at 0x1d4e65eaa20>,
#   <__main__.singleword at 0x1d4e65eab00>,
#   <__main__.singleword at 0x1d4e65eabe0>,
#   <__main__.singleword at 0x1d4e65eacc0>,
#   <__main__.singleword at 0x1d4e65eada0>,
#   <__main__.singleword at 0x1d4e65eae80>,
#   <__main__.singleword at 0x1d4e65eaf60>,
#   <__main__.singleword at 0x1d4e65e5080>,
#   <__main__.singleword at 0x1d4e65e5160>,
#   <__main__.singleword at 0x1d4e65e5240>,
#   <__main__.singleword at 0x1d4e65e5320>,
#   <__main__.singleword at 0x1d4e65e5400>,
#   <__main__.singleword at 0x1d4e65e54e0>,
#   <__main__.singleword at 0x1d4e65e55c0>,
#   <__main__.singleword at 0x1d4e65e56a0>,
#   <__main__.singleword at 0x1d4e65e5780>,
#   <__main__.singleword at 0x1d4e65e5860>,
#   <__main__.singleword at 0x1d4e65e5940>,
#   <__main__.singleword at 0x1d4e65e5a20>,
#   <__main__.singleword at 0x1d4e65e5b00>,
#   <__main__.singleword at 0x1d4e65e5be0>,
#   <__main__.singleword at 0x1d4e65e5cf8>,
#   <__main__.singleword at 0x1d4e65e5e48>,
#   <__main__.singleword at 0x1d4e65e5fd0>,
#   <__main__.singleword at 0x1d4e65e5f28>,
#   <__main__.singleword at 0x1d4e65f6128>,
#   <__main__.singleword at 0x1d4e65f6240>,
#   <__main__.singleword at 0x1d4e65f6320>,
#   <__main__.singleword at 0x1d4e65f6400>,
#   <__main__.singleword at 0x1d4e65f6518>,
#   <__main__.singleword at 0x1d4e65f6630>,
#   <__main__.singleword at 0x1d4e65f6710>,
#   <__main__.singleword at 0x1d4e65f6898>,
#   <__main__.singleword at 0x1d4e65f6978>,
#   <__main__.singleword at 0x1d4e65f6a58>,
#   <__main__.singleword at 0x1d4e65f6b38>,
#   <__main__.singleword at 0x1d4e65f6c50>,
#   <__main__.singleword at 0x1d4e65f6d30>,
#   <__main__.singleword at 0x1d4e65f6e10>,
#   <__main__.singleword at 0x1d4e65f6ef0>,
#   <__main__.singleword at 0x1d4e65f6fd0>,
#   <__main__.singleword at 0x1d4e66030f0>,
#   <__main__.singleword at 0x1d4e66031d0>,
#   <__main__.singleword at 0x1d4e66032b0>,
#   <__main__.singleword at 0x1d4e6603390>,
#   <__main__.singleword at 0x1d4e6603470>,
#   <__main__.singleword at 0x1d4e6603550>,
#   <__main__.singleword at 0x1d4e6603630>,
#   <__main__.singleword at 0x1d4e6603710>,
#   <__main__.singleword at 0x1d4e6603828>,
#   <__main__.singleword at 0x1d4e6603908>,
#   <__main__.singleword at 0x1d4e66039e8>,
#   <__main__.singleword at 0x1d4e6603ac8>,
#   <__main__.singleword at 0x1d4e6603ba8>,
#   <__main__.singleword at 0x1d4e6603cc0>,
#   <__main__.singleword at 0x1d4e6603da0>,
#   <__main__.singleword at 0x1d4e6603e80>,
#   <__main__.singleword at 0x1d4e6603f60>,
#   <__main__.singleword at 0x1d4e65fb080>,
#   <__main__.singleword at 0x1d4e65fb198>,
#   <__main__.singleword at 0x1d4e65fb2b0>,
#   <__main__.singleword at 0x1d4e65fb390>,
#   <__main__.singleword at 0x1d4e65fb4a8>,
#   <__main__.singleword at 0x1d4e65fb470>,
#   <__main__.singleword at 0x1d4e65fb668>,
#   <__main__.singleword at 0x1d4e65fb630>,
#   <__main__.singleword at 0x1d4e65fb860>,
#   <__main__.singleword at 0x1d4e65fb940>,
#   <__main__.singleword at 0x1d4e65fba20>,
#   <__main__.singleword at 0x1d4e65fbb38>,
#   <__main__.singleword at 0x1d4e65fbc18>,
#   <__main__.singleword at 0x1d4e65fbcf8>,
#   <__main__.singleword at 0x1d4e65fbe10>,
#   <__main__.singleword at 0x1d4e65fbef0>,
#   <__main__.singleword at 0x1d4e65fbfd0>,
#   <__main__.singleword at 0x1d4e65da0f0>,
#   <__main__.singleword at 0x1d4e65da208>,
#   <__main__.singleword at 0x1d4e65da2e8>,
#   <__main__.singleword at 0x1d4e65da3c8>,
#   <__main__.singleword at 0x1d4e65da4e0>,
#   <__main__.singleword at 0x1d4e65da5c0>,
#   <__main__.singleword at 0x1d4e65da6a0>,
#   <__main__.singleword at 0x1d4e65da780>,
#   <__main__.singleword at 0x1d4e65da860>,
#   <__main__.singleword at 0x1d4e65da978>,
#   <__main__.singleword at 0x1d4e65daa58>,
#   <__main__.singleword at 0x1d4e65dab38>,
#   <__main__.singleword at 0x1d4e65dac50>,
#   <__main__.singleword at 0x1d4e65dad30>,
#   <__main__.singleword at 0x1d4e65dae48>,
#   <__main__.singleword at 0x1d4e65daf28>,
#   <__main__.singleword at 0x1d4e65fd048>,
#   <__main__.singleword at 0x1d4e65fd128>,
#   <__main__.singleword at 0x1d4e65fd240>,
#   <__main__.singleword at 0x1d4e65fd320>,
#   <__main__.singleword at 0x1d4e65fd400>,
#   <__main__.singleword at 0x1d4e65fd4e0>,
#   <__main__.singleword at 0x1d4e65fd5f8>,
#   <__main__.singleword at 0x1d4e65fd5c0>,
#   <__main__.singleword at 0x1d4e65fd7b8>,
#   <__main__.singleword at 0x1d4e65fd898>,
#   <__main__.singleword at 0x1d4e65fd978>,
#   <__main__.singleword at 0x1d4e65fda90>,
#   <__main__.singleword at 0x1d4e65fdb70>,
#   <__main__.singleword at 0x1d4e65fdc88>,
#   <__main__.singleword at 0x1d4e65fdc50>,
#   <__main__.singleword at 0x1d4e65fde80>,
#   <__main__.singleword at 0x1d4e65fde48>,
#   <__main__.singleword at 0x1d4e6600048>,
#   <__main__.singleword at 0x1d4e6600128>,
#   <__main__.singleword at 0x1d4e6600278>,
#   <__main__.singleword at 0x1d4e6600390>,
#   <__main__.singleword at 0x1d4e66004a8>,
#   <__main__.singleword at 0x1d4e6600588>,
#   <__main__.singleword at 0x1d4e6600668>,
#   <__main__.singleword at 0x1d4e6600748>,
#   <__main__.singleword at 0x1d4e6600828>,
#   <__main__.singleword at 0x1d4e6600908>,
#   <__main__.singleword at 0x1d4e66009e8>,
#   <__main__.singleword at 0x1d4e6600b00>,
#   <__main__.singleword at 0x1d4e6600c18>,
#   <__main__.singleword at 0x1d4e6600d30>,
#   <__main__.singleword at 0x1d4e6600cf8>,
#   <__main__.singleword at 0x1d4e6600e10>,
#   <__main__.singleword at 0x1d4e6600fd0>,
#   <__main__.singleword at 0x1d4e65e3128>,
#   <__main__.singleword at 0x1d4e65e3208>,
#   <__main__.singleword at 0x1d4e65e32e8>,
#   <__main__.singleword at 0x1d4e65e33c8>,
#   <__main__.singleword at 0x1d4e65e34e0>,
#   <__main__.singleword at 0x1d4e65e35c0>,
#   <__main__.singleword at 0x1d4e65e36a0>,
#   <__main__.singleword at 0x1d4e65e3780>,
#   <__main__.singleword at 0x1d4e65e3860>,
#   <__main__.singleword at 0x1d4e65e3940>,
#   <__main__.singleword at 0x1d4e65e3a20>,
#   <__main__.singleword at 0x1d4e65e3b38>,
#   <__main__.singleword at 0x1d4e65e3c18>,
#   <__main__.singleword at 0x1d4e65e3cf8>,
#   <__main__.singleword at 0x1d4e65e3dd8>,
#   <__main__.singleword at 0x1d4e65e3eb8>,
#   <__main__.singleword at 0x1d4e65e3f98>,
#   <__main__.singleword at 0x1d4e65f70b8>,
#   <__main__.singleword at 0x1d4e65f7198>,
#   <__main__.singleword at 0x1d4e65f7278>,
#   <__main__.singleword at 0x1d4e65f7358>,
#   <__main__.singleword at 0x1d4e65f7438>,
#   <__main__.singleword at 0x1d4e65f7550>,
#   <__main__.singleword at 0x1d4e65f7518>,
#   <__main__.singleword at 0x1d4e65f7748>,
#   <__main__.singleword at 0x1d4e65f7828>,
#   <__main__.singleword at 0x1d4e65f7908>,
#   <__main__.singleword at 0x1d4e65f79e8>,
#   <__main__.singleword at 0x1d4e65f7ac8>,
#   <__main__.singleword at 0x1d4e65f7ba8>,
#   <__main__.singleword at 0x1d4e65f7c88>,
#   <__main__.singleword at 0x1d4e65f7d68>,
#   <__main__.singleword at 0x1d4e65f7e48>,
#   <__main__.singleword at 0x1d4e65f7f60>,
#   <__main__.singleword at 0x1d4e65f7f28>,
#   <__main__.singleword at 0x1d4e65e8160>,
#   <__main__.singleword at 0x1d4e65e8240>,
#   <__main__.singleword at 0x1d4e65e8320>,
#   <__main__.singleword at 0x1d4e65e8400>,
#   <__main__.singleword at 0x1d4e65e84e0>,
#   <__main__.singleword at 0x1d4e65e85c0>,
#   <__main__.singleword at 0x1d4e65e86a0>,
#   <__main__.singleword at 0x1d4e65e8780>,
#   <__main__.singleword at 0x1d4e65e8860>,
#   <__main__.singleword at 0x1d4e65e8978>,
#   <__main__.singleword at 0x1d4e65e8a58>,
#   <__main__.singleword at 0x1d4e65e8b38>,
#   <__main__.singleword at 0x1d4e65e8c18>,
#   <__main__.singleword at 0x1d4e65e8cf8>,
#   <__main__.singleword at 0x1d4e65e8dd8>,
#   <__main__.singleword at 0x1d4e65e8eb8>,
#   <__main__.singleword at 0x1d4e65e8f98>,
#   <__main__.singleword at 0x1d4e65e90b8>,
#   <__main__.singleword at 0x1d4e65e91d0>,
#   <__main__.singleword at 0x1d4e65e92b0>,
#   <__main__.singleword at 0x1d4e65e9390>,
#   <__main__.singleword at 0x1d4e65e94a8>,
#   <__main__.singleword at 0x1d4e65e95c0>,
#   <__main__.singleword at 0x1d4e65e9588>,
#   <__main__.singleword at 0x1d4e65e9780>,
#   <__main__.singleword at 0x1d4e65e9860>,
#   <__main__.singleword at 0x1d4e65e9940>,
#   <__main__.singleword at 0x1d4e65e9a20>,
#   <__main__.singleword at 0x1d4e65e9b00>,
#   <__main__.singleword at 0x1d4e65e9be0>,
#   <__main__.singleword at 0x1d4e65e9cc0>,
#   <__main__.singleword at 0x1d4e65e9da0>,
#   <__main__.singleword at 0x1d4e65e9eb8>,
#   <__main__.singleword at 0x1d4e65e9f98>,
#   <__main__.singleword at 0x1d4e65d40b8>,
#   <__main__.singleword at 0x1d4e65d4198>,
#   <__main__.singleword at 0x1d4e65d4278>,
#   <__main__.singleword at 0x1d4e65d4358>,
#   <__main__.singleword at 0x1d4e65d4438>,
#   <__main__.singleword at 0x1d4e65d4550>,
#   <__main__.singleword at 0x1d4e65d4630>,
#   <__main__.singleword at 0x1d4e65d4710>,
#   <__main__.singleword at 0x1d4e65d47f0>,
#   <__main__.singleword at 0x1d4e65d48d0>,
#   <__main__.singleword at 0x1d4e65d49b0>,
#   <__main__.singleword at 0x1d4e65d4a90>,
#   <__main__.singleword at 0x1d4e65d4b70>,
#   <__main__.singleword at 0x1d4e65d4c50>,
#   <__main__.singleword at 0x1d4e65d4d30>,
#   <__main__.singleword at 0x1d4e65d4e10>,
#   <__main__.singleword at 0x1d4e65d4f28>,
#   <__main__.singleword at 0x1d4e65d2048>,
#   <__main__.singleword at 0x1d4e65d2128>,
#   <__main__.singleword at 0x1d4e65d2208>,
#   <__main__.singleword at 0x1d4e65d22e8>,
#   <__main__.singleword at 0x1d4e65d23c8>,
#   <__main__.singleword at 0x1d4e65d24a8>,
#   <__main__.singleword at 0x1d4e65d2588>,
#   <__main__.singleword at 0x1d4e65d2668>,
#   <__main__.singleword at 0x1d4e65d2748>,
#   <__main__.singleword at 0x1d4e65d2860>,
#   <__main__.singleword at 0x1d4e65d2828>,
#   <__main__.singleword at 0x1d4e65d2a20>,
#   <__main__.singleword at 0x1d4e65d2b00>,
#   <__main__.singleword at 0x1d4e65d2be0>,
#   <__main__.singleword at 0x1d4e65d2cc0>,
#   <__main__.singleword at 0x1d4e65d2da0>,
#   <__main__.singleword at 0x1d4e65d2ef0>,
#   <__main__.singleword at 0x1d4e65d2eb8>,
#   <__main__.singleword at 0x1d4e65de128>,
#   <__main__.singleword at 0x1d4e65de0f0>,
#   <__main__.singleword at 0x1d4e65de278>,
#   <__main__.singleword at 0x1d4e65de358>,
#   <__main__.singleword at 0x1d4e65de438>,
#   <__main__.singleword at 0x1d4e65de550>,
#   <__main__.singleword at 0x1d4e65de630>,
#   <__main__.singleword at 0x1d4e65de710>,
#   <__main__.singleword at 0x1d4e65de7f0>,
#   <__main__.singleword at 0x1d4e65de8d0>,
#   <__main__.singleword at 0x1d4e65de9b0>,
#   <__main__.singleword at 0x1d4e65dea90>,
#   <__main__.singleword at 0x1d4e65deb70>,
#   <__main__.singleword at 0x1d4e65dec88>,
#   <__main__.singleword at 0x1d4e65ded68>,
#   <__main__.singleword at 0x1d4e65dee48>,
#   <__main__.singleword at 0x1d4e65def60>,
#   <__main__.singleword at 0x1d4e65ef080>,
#   <__main__.singleword at 0x1d4e65ef160>,
#   <__main__.singleword at 0x1d4e65ef240>,
#   <__main__.singleword at 0x1d4e65ef320>,
#   <__main__.singleword at 0x1d4e65ef400>,
#   <__main__.singleword at 0x1d4e65ef4e0>,
#   <__main__.singleword at 0x1d4e65ef5c0>,
#   <__main__.singleword at 0x1d4e65ef6a0>,
#   <__main__.singleword at 0x1d4e65ef780>,
#   <__main__.singleword at 0x1d4e65ef860>,
#   <__main__.singleword at 0x1d4e65ef940>,
#   <__main__.singleword at 0x1d4e65efa20>,
#   <__main__.singleword at 0x1d4e65efb00>,
#   <__main__.singleword at 0x1d4e65efbe0>,
#   <__main__.singleword at 0x1d4e65efc88>,
#   <__main__.singleword at 0x1d4e65efda0>,
#   <__main__.singleword at 0x1d4e65efeb8>,
#   <__main__.singleword at 0x1d4e65efe80>,
#   <__main__.singleword at 0x1d4e65d6080>,
#   <__main__.singleword at 0x1d4e65d6160>,
#   <__main__.singleword at 0x1d4e65d6240>,
#   <__main__.singleword at 0x1d4e65d6358>,
#   <__main__.singleword at 0x1d4e65d6470>,
#   <__main__.singleword at 0x1d4e65d6550>,
#   <__main__.singleword at 0x1d4e65d6630>,
#   <__main__.singleword at 0x1d4e65d6710>,
#   <__main__.singleword at 0x1d4e65d67f0>,
#   <__main__.singleword at 0x1d4e65d68d0>,
#   <__main__.singleword at 0x1d4e65d69b0>,
#   <__main__.singleword at 0x1d4e65d6a90>,
#   <__main__.singleword at 0x1d4e65d6b70>,
#   <__main__.singleword at 0x1d4e65d6c88>,
#   <__main__.singleword at 0x1d4e65d6d68>,
#   <__main__.singleword at 0x1d4e65d6e48>,
#   <__main__.singleword at 0x1d4e65d6f28>,
#   <__main__.singleword at 0x1d4e65d1048>,
#   <__main__.singleword at 0x1d4e65d1128>,
#   <__main__.singleword at 0x1d4e65d1208>,
#   <__main__.singleword at 0x1d4e65d12e8>,
#   <__main__.singleword at 0x1d4e65d13c8>,
#   <__main__.singleword at 0x1d4e65d14a8>,
#   <__main__.singleword at 0x1d4e65d1588>,
#   <__main__.singleword at 0x1d4e65d16a0>,
#   <__main__.singleword at 0x1d4e65d1780>,
#   <__main__.singleword at 0x1d4e65d1860>,
#   <__main__.singleword at 0x1d4e65d1940>,
#   <__main__.singleword at 0x1d4e65d1a20>,
#   <__main__.singleword at 0x1d4e65d1b00>,
#   <__main__.singleword at 0x1d4e65d1be0>,
#   <__main__.singleword at 0x1d4e65d1cf8>,
#   <__main__.singleword at 0x1d4e65d1dd8>,
#   <__main__.singleword at 0x1d4e65d1eb8>,
#   <__main__.singleword at 0x1d4e65d1f98>,
#   <__main__.singleword at 0x1d4e66040b8>,
#   <__main__.singleword at 0x1d4e6604198>,
#   <__main__.singleword at 0x1d4e66042b0>,
#   <__main__.singleword at 0x1d4e6604390>,
#   <__main__.singleword at 0x1d4e6604470>,
#   <__main__.singleword at 0x1d4e6604588>,
#   <__main__.singleword at 0x1d4e6604668>,
#   <__main__.singleword at 0x1d4e6604748>,
#   <__main__.singleword at 0x1d4e6604828>,
#   <__main__.singleword at 0x1d4e6604908>,
#   <__main__.singleword at 0x1d4e6604a20>,
#   <__main__.singleword at 0x1d4e6604b00>,
#   <__main__.singleword at 0x1d4e6604be0>,
#   <__main__.singleword at 0x1d4e6604cf8>,
#   <__main__.singleword at 0x1d4e6604dd8>,
#   <__main__.singleword at 0x1d4e6604eb8>,
#   <__main__.singleword at 0x1d4e6604f98>,
#   <__main__.singleword at 0x1d4e65dd0f0>,
#   <__main__.singleword at 0x1d4e65dd1d0>,
#   <__main__.singleword at 0x1d4e65dd2e8>,
#   <__main__.singleword at 0x1d4e65dd3c8>,
#   <__main__.singleword at 0x1d4e65dd4a8>,
#   <__main__.singleword at 0x1d4e65dd588>,
#   <__main__.singleword at 0x1d4e65dd668>,
#   <__main__.singleword at 0x1d4e65dd780>,
#   <__main__.singleword at 0x1d4e65dd860>,
#   <__main__.singleword at 0x1d4e65dd940>,
#   <__main__.singleword at 0x1d4e65dda20>,
#   <__main__.singleword at 0x1d4e65ddb00>,
#   <__main__.singleword at 0x1d4e65ddbe0>,
#   <__main__.singleword at 0x1d4e65ddcc0>,
#   <__main__.singleword at 0x1d4e65ddda0>,
#   <__main__.singleword at 0x1d4e65dde80>,
#   <__main__.singleword at 0x1d4e65ddf98>,
#   <__main__.singleword at 0x1d4e65ddf60>,
#   <__main__.singleword at 0x1d4e65e0198>,
#   <__main__.singleword at 0x1d4e65e0278>,
#   <__main__.singleword at 0x1d4e65e0358>,
#   <__main__.singleword at 0x1d4e65e0438>,
#   <__main__.singleword at 0x1d4e65e0518>,
#   <__main__.singleword at 0x1d4e65e05f8>,
#   <__main__.singleword at 0x1d4e65e06d8>,
#   <__main__.singleword at 0x1d4e65e07b8>,
#   <__main__.singleword at 0x1d4e65e0898>,
#   <__main__.singleword at 0x1d4e65e0978>,
#   <__main__.singleword at 0x1d4e65e0a58>,
#   <__main__.singleword at 0x1d4e65e0b38>,
#   <__main__.singleword at 0x1d4e65e0c50>,
#   <__main__.singleword at 0x1d4e65e0d30>,
#   <__main__.singleword at 0x1d4e65e0e48>,
#   <__main__.singleword at 0x1d4e65e0f28>,
#   <__main__.singleword at 0x1d4e65df080>,
#   <__main__.singleword at 0x1d4e65df160>,
#   <__main__.singleword at 0x1d4e65df240>,
#   <__main__.singleword at 0x1d4e65df358>,
#   <__main__.singleword at 0x1d4e65df438>,
#   <__main__.singleword at 0x1d4e65df550>,
#   <__main__.singleword at 0x1d4e65df630>,
#   <__main__.singleword at 0x1d4e65df710>,
#   <__main__.singleword at 0x1d4e65df7f0>,
#   <__main__.singleword at 0x1d4e65df908>,
#   <__main__.singleword at 0x1d4e65df8d0>,
#   <__main__.singleword at 0x1d4e65dfac8>,
#   <__main__.singleword at 0x1d4e65dfba8>,
#   <__main__.singleword at 0x1d4e65dfc88>,
#   <__main__.singleword at 0x1d4e65dfda0>,
#   <__main__.singleword at 0x1d4e65dfeb8>,
#   <__main__.singleword at 0x1d4e65dff98>,
#   <__main__.singleword at 0x1d4e65d70b8>,
#   <__main__.singleword at 0x1d4e65d7198>,
#   <__main__.singleword at 0x1d4e65d7278>,
#   <__main__.singleword at 0x1d4e65d7390>,
#   <__main__.singleword at 0x1d4e65d7358>,
#   <__main__.singleword at 0x1d4e65d7588>,
#   <__main__.singleword at 0x1d4e65d7550>,
#   <__main__.singleword at 0x1d4e65d7710>,
#   <__main__.singleword at 0x1d4e65d7828>,
#   <__main__.singleword at 0x1d4e65d7908>,
#   <__main__.singleword at 0x1d4e65d7a20>,
#   <__main__.singleword at 0x1d4e65d7b00>,
#   <__main__.singleword at 0x1d4e65d7be0>,
#   <__main__.singleword at 0x1d4e65d7cc0>,
#   <__main__.singleword at 0x1d4e65d7da0>,
#   <__main__.singleword at 0x1d4e65d7e80>,
#   <__main__.singleword at 0x1d4e65d7f60>,
#   <__main__.singleword at 0x1d4e65f2080>,
#   <__main__.singleword at 0x1d4e65f2160>,
#   <__main__.singleword at 0x1d4e65f2278>,
#   <__main__.singleword at 0x1d4e65f2358>,
#   <__main__.singleword at 0x1d4e65f2470>,
#   <__main__.singleword at 0x1d4e65f2550>,
#   <__main__.singleword at 0x1d4e65f2630>,
#   <__main__.singleword at 0x1d4e65f2710>,
#   <__main__.singleword at 0x1d4e65f2828>,
#   <__main__.singleword at 0x1d4e65f2908>,
#   <__main__.singleword at 0x1d4e65f29e8>,
#   <__main__.singleword at 0x1d4e65f2ac8>,
#   <__main__.singleword at 0x1d4e65f2ba8>,
#   <__main__.singleword at 0x1d4e65f2c88>,
#   <__main__.singleword at 0x1d4e65f2d68>,
#   <__main__.singleword at 0x1d4e65f2e48>,
#   <__main__.singleword at 0x1d4e65f2f28>,
#   <__main__.singleword at 0x1d4e65e6048>,
#   <__main__.singleword at 0x1d4e65e6160>,
#   <__main__.singleword at 0x1d4e65e6240>,
#   <__main__.singleword at 0x1d4e65e6358>,
#   <__main__.singleword at 0x1d4e65e6438>,
#   <__main__.singleword at 0x1d4e65e6518>,
#   <__main__.singleword at 0x1d4e65e65f8>,
#   <__main__.singleword at 0x1d4e65e6710>,
#   <__main__.singleword at 0x1d4e65e6828>,
#   <__main__.singleword at 0x1d4e65e67f0>,
#   <__main__.singleword at 0x1d4e65e6a58>,
#   <__main__.singleword at 0x1d4e65e6a20>,
#   <__main__.singleword at 0x1d4e65e6c18>,
#   <__main__.singleword at 0x1d4e65e6d30>,
#   <__main__.singleword at 0x1d4e65e6cf8>,
#   <__main__.singleword at 0x1d4e65e6ef0>,
#   <__main__.singleword at 0x1d4e65e6fd0>,
#   <__main__.singleword at 0x1d4e65f80f0>,
#   <__main__.singleword at 0x1d4e65f81d0>,
#   <__main__.singleword at 0x1d4e65f82e8>,
#   <__main__.singleword at 0x1d4e65f83c8>,
#   <__main__.singleword at 0x1d4e65f84a8>,
#   <__main__.singleword at 0x1d4e65f8588>,
#   <__main__.singleword at 0x1d4e65f8668>,
#   <__main__.singleword at 0x1d4e65f8748>,
#   <__main__.singleword at 0x1d4e65f8828>,
#   <__main__.singleword at 0x1d4e65f8908>,
#   <__main__.singleword at 0x1d4e65f89e8>,
#   <__main__.singleword at 0x1d4e65f8ac8>,
#   <__main__.singleword at 0x1d4e65f8ba8>,
#   <__main__.singleword at 0x1d4e65f8c88>,
#   <__main__.singleword at 0x1d4e65f8d68>,
#   <__main__.singleword at 0x1d4e65f8e48>,
#   <__main__.singleword at 0x1d4e65f8f28>,
#   <__main__.singleword at 0x1d4e65fe048>,
#   <__main__.singleword at 0x1d4e65fe128>,
#   <__main__.singleword at 0x1d4e65fe240>,
#   <__main__.singleword at 0x1d4e65fe320>,
#   <__main__.singleword at 0x1d4e65fe400>,
#   <__main__.singleword at 0x1d4e65fe4e0>,
#   <__main__.singleword at 0x1d4e65fe5c0>,
#   <__main__.singleword at 0x1d4e65fe6a0>,
#   <__main__.singleword at 0x1d4e65fe7b8>,
#   <__main__.singleword at 0x1d4e65fe8d0>,
#   <__main__.singleword at 0x1d4e65fe9b0>,
#   <__main__.singleword at 0x1d4e65feac8>,
#   <__main__.singleword at 0x1d4e65feba8>,
#   <__main__.singleword at 0x1d4e65fec88>,
#   <__main__.singleword at 0x1d4e65fed68>,
#   <__main__.singleword at 0x1d4e65fee48>,
#   <__main__.singleword at 0x1d4e65fef28>,
#   <__main__.singleword at 0x1d4e6601048>,
#   <__main__.singleword at 0x1d4e6601128>,
#   <__main__.singleword at 0x1d4e6601208>,
#   <__main__.singleword at 0x1d4e66012e8>,
#   <__main__.singleword at 0x1d4e66013c8>,
#   <__main__.singleword at 0x1d4e66014e0>,
#   <__main__.singleword at 0x1d4e66014a8>,
#   <__main__.singleword at 0x1d4e66016a0>,
#   <__main__.singleword at 0x1d4e6601780>,
#   <__main__.singleword at 0x1d4e6601860>,
#   <__main__.singleword at 0x1d4e6601978>,
#   <__main__.singleword at 0x1d4e6601a90>,
#   <__main__.singleword at 0x1d4e6601a58>,
#   <__main__.singleword at 0x1d4e6601c88>,
#   <__main__.singleword at 0x1d4e6601c50>,
#   <__main__.singleword at 0x1d4e6601e48>,
#   <__main__.singleword at 0x1d4e6601f28>,
#   <__main__.singleword at 0x1d4e65d0048>,
#   <__main__.singleword at 0x1d4e65d0128>,
#   <__main__.singleword at 0x1d4e65d0208>,
#   <__main__.singleword at 0x1d4e65d02e8>,
#   <__main__.singleword at 0x1d4e65d03c8>,
#   <__main__.singleword at 0x1d4e65d04e0>,
#   <__main__.singleword at 0x1d4e65d05c0>,
#   <__main__.singleword at 0x1d4e65d06a0>,
#   <__main__.singleword at 0x1d4e65d0780>,
#   <__main__.singleword at 0x1d4e65d0860>,
#   <__main__.singleword at 0x1d4e65d0978>,
#   <__main__.singleword at 0x1d4e65d0ac8>,
#   <__main__.singleword at 0x1d4e65d0a90>,
#   <__main__.singleword at 0x1d4e65d0c88>,
#   <__main__.singleword at 0x1d4e65d0da0>,
#   <__main__.singleword at 0x1d4e65d0e80>,
#   <__main__.singleword at 0x1d4e65d0f60>,
#   <__main__.singleword at 0x1d4e65ff0b8>,
#   <__main__.singleword at 0x1d4e65ff080>,
#   <__main__.singleword at 0x1d4e65ff278>,
#   <__main__.singleword at 0x1d4e65ff390>,
#   <__main__.singleword at 0x1d4e65ff470>,
#   <__main__.singleword at 0x1d4e65ff550>,
#   <__main__.singleword at 0x1d4e65ff630>,
#   <__main__.singleword at 0x1d4e65ff710>,
#   <__main__.singleword at 0x1d4e65ff828>,
#   <__main__.singleword at 0x1d4e65ff908>,
#   <__main__.singleword at 0x1d4e65ff9e8>,
#   <__main__.singleword at 0x1d4e65ffac8>,
#   <__main__.singleword at 0x1d4e65ffba8>,
#   <__main__.singleword at 0x1d4e65ffc88>,
#   <__main__.singleword at 0x1d4e65ffd68>,
#   <__main__.singleword at 0x1d4e65ffe48>,
#   <__main__.singleword at 0x1d4e65fff60>,
#   <__main__.singleword at 0x1d4e65e2080>,
#   <__main__.singleword at 0x1d4e65e2198>,
#   <__main__.singleword at 0x1d4e65e2278>,
#   <__main__.singleword at 0x1d4e65e2390>,
#   <__main__.singleword at 0x1d4e65e2358>,
#   <__main__.singleword at 0x1d4e65e2588>,
#   <__main__.singleword at 0x1d4e65e26a0>,
#   <__main__.singleword at 0x1d4e65e2668>,
#   <__main__.singleword at 0x1d4e65e2780>,
#   <__main__.singleword at 0x1d4e65e29b0>,
#   <__main__.singleword at 0x1d4e65e2978>,
#   <__main__.singleword at 0x1d4e65e2b38>,
#   <__main__.singleword at 0x1d4e65e2c18>,
#   <__main__.singleword at 0x1d4e65e2cf8>,
#   <__main__.singleword at 0x1d4e65e2dd8>,
#   ...]]

# %%
# input
from sklearn.feature_extraction.text import CountVectorizer
def counter(word,by=0):
    vectorizer = CountVectorizer(ngram_range=(1, 1), lowercase=False, token_pattern = r'\b\w+\b', min_df = 1)
    if(by==0):
        word=[" ".join(x.split("")) for x in word]
        tf_mat = vectorizer.fit_transform(word)
    else:
        temp=[]
        for i in word:
            s=""
            for x in i:
                if (x.type in by):
                    s=s+","+x.word
                    x.show()
            temp.append(s)
        tf_mat = vectorizer.fit_transform(temp)
    return (vectorizer.get_feature_names(),tf_mat.toarray())

# %%
t=counter([b.content],by=["n","nsf"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-140-77e75d5c4fc3> in <module>()
# ----> 1 t=counter([b.content],by=["n","nsf"])
#
# NameError: name 'b' is not defined

# %%
t[1]

# %%
class article_first_layer:
    def __init__(self,wordveclist,d="article"):
        self.wordveclist=wordveclist
        self.page=0
        self.wordvec=wordveclist[self.page]
        self.indexlen=len(self.wordvec)-1
        self.point=0
        self.dtype=d
    def nextpage(self):
        if(self.page<len(self.wordveclist)-1):
            page+=1
            self.wordvec=wordveclist[self.page]
            self.point=0
            return True
        else:
            return False
    def to_standard_type(self):
        
        return [singleword([0,0,0,0,0,0,0])]+[singleword(self.wordvec[i]) for i in range(1,len(self.wordvec))]
    """
    def action(self,x=[False]):
        if(x[0]=="W"):
            return (self.wordvec[x[1]][0])
        elif(x[0]=="T"):
            return (self.wordvec[x[1]][2])
        elif(x[0]=="C"):
            return (self.wordvec[x[1]][0],self.wordvec[x[1]][3],self.wordvec[x[1]][4])
        elif(x[0]=="N"):
            if(self.point<self.indexlen):
                self.point+=1
                return point
            else:
                return False    
        elif(x[0]=="B"):
            if(self.point<self.indexlen):
                self.point+=1
                return point
            else:
                return False
        else:
            print("somewhere got wrong")
            """

# %%
class article_second_layer_sentence:
    def read_sentence(self,pointer):
        p=pointer
        re=[]
        while(True):]
            if(p<=1 or p>=self.contentlen): 
                break
            elif(self.sp_type(p)!=1):
                p-=1
            else:
                p+=1
                break
        while(True):
            if(p>=self.contentlen):
                p=-1
                print("out of range")
                break
            elif(self.sp_type(p)!=1):
                re.append(self.content[p])
            else:
                break
            p+=1
        return (re,p)
    def sp_type(self,wordp):
        word=self.content[wordp]
        
        if(word.word=="," or word.word=="。" or word.word=="，"):
            return 1
        else:
            return 0

# %%
class article_second_layer(article_second_layer_sentence):
    def __init__(self,firstlayer):
        self.content=firstlayer.to_standard_type()
        self.contentlen=len(self.content)
        #self.content=article_first_layer(newtxtlist)
    def show_sentence(self,s):
        print([x.word for x in s[0]])
    def wordlink(self,link=["ns","n","nsf "]):

# %%
a=article_first_layer(newtxtlist)
b=article_second_layer(a)

# %%
b.show_sentence(b.read_sentence(7890))

# %%
for i in range(len(b.content)):
    print(i,end=" ")
    b.content[i].show()

# %%
for i in b.content:
    if(i.word in spot or i.type=="nsf" or i.type== "ns"):
        print(i.word)
